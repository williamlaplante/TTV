# %%
import torch as tc
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from scipy.stats import norm, multivariate_normal
sys.path.append(r'../') #path to folder where file that stored the results is located
from utils import calculate_effective_sample_size

plt.rc('font', family='serif', size=14)
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

# %%
run = "./run_2022-12-03_12-53-09/"

# %%
with open(run + "graphical_model.pkl", "rb") as f:
    model = pickle.load(f)

observed = []
observed_dict = {}
for var in model.topological():
    if var in model.Graph["Y"].keys():
        observed.append(tc.tensor(model.Graph["Y"][var]).float())
        observed_dict.update({var : tc.tensor(model.Graph["Y"][var]).float()})

observed = tc.stack(observed)
print("observed : {}".format(observed))
# Out:
# observed : tensor([ 5.3000, 12.9000, 10.2000,  3.9000,  7.7000,  2.1000])

# %%
def get_samples(epoch, observed, observed_dict, num_samples=2000):
    proposal_samples = []
    proposal_weights = []
    model_weights = []
    weights = []
    with open(run + "proposal_epoch{}.pkl".format(epoch), "rb") as f:
        proposal = pickle.load(f)
    with open(run + "/model.pkl", "rb") as f:
        model = pickle.load(f)


    for i in range(num_samples):
        sample_dict = proposal.sample(y = observed)
        sample_tensor = tc.stack([sample_dict[latent] for latent in model.latent_ordered_vars]) #topological order
        proposal_samples.append(sample_tensor) #sample in the topological order
        model_weights.append(model.log_prob({**sample_dict, **observed_dict}).detach().clone())
        proposal_weights.append(proposal.log_prob(sample_tensor, observed).detach().clone())
        weights.append(tc.exp(model_weights[i] - proposal_weights[i]))
        print("=> proposal weight : {}, model weight : {}, sample : {}".format(proposal_weights[i], model_weights[i], sample_tensor))

    proposal_samples = tc.stack(proposal_samples)
    proposal_weights = tc.stack(proposal_weights)
    model_weights = tc.stack(model_weights)
    calculate_effective_sample_size(tc.stack(weights), verbose=True)
    weights = tc.stack(weights).numpy()
    weights /= weights.sum()
    

    idx = np.random.choice(np.arange(len(weights)), size=len(weights), p=weights)
    resamples = proposal_samples[idx]
    return proposal_samples, resamples

# %%
proposal_samples, samples = get_samples(epoch = 5, observed = observed, observed_dict=observed_dict, num_samples=3000)
proposal_samples = proposal_samples.numpy()
samples = samples.numpy()
# Out:
# => proposal weight : 0.04236161708831787, model weight : -12.510115623474121, sample : tensor([ 2.1373, -0.5007])
# => proposal weight : -1.4040515422821045, model weight : -15.50696849822998, sample : tensor([ 2.6971, -2.0754])
# => proposal weight : -0.6072551012039185, model weight : -13.776674270629883, sample : tensor([1.9930, 0.6341])
# => proposal weight : -0.05391204357147217, model weight : -12.880925178527832, sample : tensor([ 2.3555, -1.2448])
# => proposal weight : 0.09870845079421997, model weight : -13.153176307678223, sample : tensor([ 2.3152, -0.7175])
# => proposal weight : 0.1722227931022644, model weight : -12.643388748168945, sample : tensor([ 2.1573, -0.3187])
# => proposal weight : 0.09060484170913696, model weight : -13.042437553405762, sample : tensor([ 2.3434, -0.9219])
# => proposal weight : -0.7469756603240967, model weight : -13.437675476074219, sample : tensor([ 2.4005, -1.7367])
# => proposal weight : -0.6735192537307739, model weight : -13.35695743560791, sample : tensor([ 2.3892, -1.6819])
# => proposal weight : -0.2058478593826294, model weight : -12.743349075317383, sample : tensor([ 2.2269, -1.0247])
# => proposal weight : -0.4964316487312317, model weight : -14.616778373718262, sample : tensor([ 2.3156, -0.2977])
# => proposal weight : 0.023235082626342773, model weight : -12.544611930847168, sample : tensor([ 2.0859, -0.2440])
# => proposal weight : -0.4738386869430542, model weight : -12.86073112487793, sample : tensor([ 1.9782, -0.0882])
# => proposal weight : 0.03847074508666992, model weight : -13.018640518188477, sample : tensor([ 2.1288, -0.0215])
# => proposal weight : -0.9218053817749023, model weight : -13.283453941345215, sample : tensor([ 1.9837, -0.3494])
# => proposal weight : -0.27401745319366455, model weight : -12.710920333862305, sample : tensor([ 2.1202, -0.6605])
# => proposal weight : -3.857766628265381, model weight : -17.041086196899414, sample : tensor([ 2.8217, -3.2820])
# => proposal weight : -0.5954259634017944, model weight : -13.590042114257812, sample : tensor([ 2.4969, -1.8003])
# => proposal weight : -0.15489518642425537, model weight : -13.119284629821777, sample : tensor([2.0434, 0.2792])
# => proposal weight : -0.16678965091705322, model weight : -12.70620346069336, sample : tensor([2.0025, 0.0709])
# => proposal weight : -2.7291336059570312, model weight : -18.010631561279297, sample : tensor([ 2.8843, -2.5767])
# => proposal weight : -0.26494473218917847, model weight : -14.074241638183594, sample : tensor([ 2.2728, -0.2455])
# => proposal weight : -0.15072476863861084, model weight : -12.698915481567383, sample : tensor([2.0068, 0.0647])
# => proposal weight : -0.20669519901275635, model weight : -13.512981414794922, sample : tensor([ 2.4552, -1.3271])
# => proposal weight : -0.319455623626709, model weight : -14.216012001037598, sample : tensor([ 2.2909, -0.2852])
# => proposal weight : -1.4983247518539429, model weight : -14.833566665649414, sample : tensor([ 2.6609, -2.3749])
# => proposal weight : -0.14084994792938232, model weight : -12.86992073059082, sample : tensor([2.0084, 0.2391])
# => proposal weight : 0.12785452604293823, model weight : -12.530044555664062, sample : tensor([ 2.1371, -0.3728])
# => proposal weight : -0.1567378044128418, model weight : -12.627965927124023, sample : tensor([ 2.1426, -0.6840])
# => proposal weight : -0.10381841659545898, model weight : -13.345102310180664, sample : tensor([ 2.4236, -1.2209])
# => proposal weight : -0.8691684007644653, model weight : -13.62419605255127, sample : tensor([ 2.4495, -1.8826])
# => proposal weight : -2.0505642890930176, model weight : -15.317472457885742, sample : tensor([1.8685, 1.3157])
# => proposal weight : -0.19262731075286865, model weight : -12.931167602539062, sample : tensor([ 2.3546, -1.3571])
# => proposal weight : -1.4345364570617676, model weight : -13.853540420532227, sample : tensor([ 1.9684, -0.4669])
# => proposal weight : -0.3870924115180969, model weight : -12.803473472595215, sample : tensor([ 2.1036, -0.6508])
# => proposal weight : -3.565713405609131, model weight : -17.525598526000977, sample : tensor([1.4480, 1.4673])
# => proposal weight : -0.5153224468231201, model weight : -13.209630966186523, sample : tensor([ 2.3800, -1.5910])
# => proposal weight : -3.718388795852661, model weight : -16.451671600341797, sample : tensor([ 2.4497, -2.5787])
# => proposal weight : -0.6807231903076172, model weight : -13.048373222351074, sample : tensor([ 2.0227, -0.4285])
# => proposal weight : -0.022414088249206543, model weight : -13.398615837097168, sample : tensor([ 2.2031, -0.1556])
# => proposal weight : -0.9979664087295532, model weight : -13.688898086547852, sample : tensor([1.7962, 0.8978])
# => proposal weight : -0.560016393661499, model weight : -14.464534759521484, sample : tensor([2.1921, 0.1496])
# => proposal weight : -0.3253815174102783, model weight : -13.495034217834473, sample : tensor([ 2.4776, -1.5376])
# => proposal weight : -0.8124886751174927, model weight : -15.194243431091309, sample : tensor([ 2.4854, -0.9288])
# => proposal weight : 0.1701958179473877, model weight : -12.573984146118164, sample : tensor([ 2.2256, -0.6947])
# => proposal weight : -0.1540381908416748, model weight : -13.441658020019531, sample : tensor([ 2.4395, -1.2647])
# => proposal weight : -0.34072649478912354, model weight : -13.716655731201172, sample : tensor([2.0965, 0.3080])
# => proposal weight : 0.15933048725128174, model weight : -12.604164123535156, sample : tensor([ 2.2475, -0.7791])
# => proposal weight : -0.37472671270370483, model weight : -14.268529891967773, sample : tensor([ 2.4341, -0.9094])
# => proposal weight : -0.9360619783401489, model weight : -13.469456672668457, sample : tensor([ 2.2118, -1.2800])
# => proposal weight : -0.2554903030395508, model weight : -12.780189514160156, sample : tensor([ 2.2215, -1.0337])
# => proposal weight : -0.30211079120635986, model weight : -12.906353950500488, sample : tensor([ 2.2954, -1.2820])
# => proposal weight : -0.05048060417175293, model weight : -13.00015926361084, sample : tensor([2.0719, 0.1494])
# => proposal weight : -0.528949499130249, model weight : -13.305936813354492, sample : tensor([ 2.4223, -1.6777])
# => proposal weight : -0.7782453298568726, model weight : -13.659370422363281, sample : tensor([ 2.4904, -1.9035])
# => proposal weight : -0.19865214824676514, model weight : -13.043999671936035, sample : tensor([2.0083, 0.3359])
# => proposal weight : -0.17388439178466797, model weight : -12.779548645019531, sample : tensor([ 2.2772, -1.1604])
# => proposal weight : -1.2102179527282715, model weight : -13.59853458404541, sample : tensor([ 1.9763, -0.4262])
# => proposal weight : -2.9649698734283447, model weight : -17.56263542175293, sample : tensor([2.0751, 1.0453])
# => proposal weight : -0.6744736433029175, model weight : -13.572884559631348, sample : tensor([ 2.4832, -1.8397])
# => proposal weight : -0.08061206340789795, model weight : -13.305126190185547, sample : tensor([ 2.4158, -1.1956])
# => proposal weight : -1.8367010354995728, model weight : -14.513168334960938, sample : tensor([ 2.4368, -2.1620])
# => proposal weight : -1.7979779243469238, model weight : -14.373883247375488, sample : tensor([1.7454, 0.5270])
# => proposal weight : -0.37491273880004883, model weight : -13.204851150512695, sample : tensor([ 2.4202, -1.5842])
# => proposal weight : -0.10646486282348633, model weight : -13.527931213378906, sample : tensor([ 2.1801, -0.0316])
# => proposal weight : -3.2639873027801514, model weight : -17.028043746948242, sample : tensor([1.4729, 1.4543])
# => proposal weight : -0.6602612733840942, model weight : -14.651604652404785, sample : tensor([ 2.5296, -1.2952])
# => proposal weight : -0.03008955717086792, model weight : -12.621658325195312, sample : tensor([ 2.2333, -0.9334])
# => proposal weight : -2.116802930831909, model weight : -17.42804718017578, sample : tensor([ 2.6982, -1.5546])
# => proposal weight : -1.0794914960861206, model weight : -15.36817741394043, sample : tensor([ 2.6073, -1.5249])
# => proposal weight : -0.42382121086120605, model weight : -12.810723304748535, sample : tensor([ 2.0010, -0.1803])
# => proposal weight : -0.7721552848815918, model weight : -13.501059532165527, sample : tensor([1.8527, 0.8028])
# => proposal weight : -0.5338714122772217, model weight : -12.906414031982422, sample : tensor([ 1.9824, -0.1502])
# => proposal weight : -0.15964293479919434, model weight : -12.725650787353516, sample : tensor([ 2.2442, -1.0535])
# => proposal weight : 0.1784490942955017, model weight : -12.892974853515625, sample : tensor([ 2.2572, -0.5737])
# => proposal weight : -1.1663246154785156, model weight : -15.918949127197266, sample : tensor([ 2.5114, -0.9037])
# => proposal weight : -0.09049773216247559, model weight : -12.82983112335205, sample : tensor([ 2.3335, -1.2411])
# => proposal weight : -0.32558441162109375, model weight : -12.794194221496582, sample : tensor([1.9684, 0.1058])
# => proposal weight : -0.4811074733734131, model weight : -13.761438369750977, sample : tensor([2.0429, 0.4872])
# => proposal weight : -1.1948734521865845, model weight : -14.018351554870605, sample : tensor([ 2.5119, -2.1152])
# => proposal weight : -0.2537587881088257, model weight : -13.627361297607422, sample : tensor([ 2.4680, -1.3440])
# => proposal weight : -0.6991639137268066, model weight : -14.162715911865234, sample : tensor([ 2.5690, -1.7849])
# => proposal weight : -2.489217519760132, model weight : -17.62928009033203, sample : tensor([ 2.8474, -2.4194])
# => proposal weight : -0.10865253210067749, model weight : -12.582014083862305, sample : tensor([ 2.0654, -0.2838])
# => proposal weight : -0.8444859981536865, model weight : -13.704505920410156, sample : tensor([ 2.4909, -1.9368])
# => proposal weight : 0.16355806589126587, model weight : -12.542647361755371, sample : tensor([ 2.1650, -0.4507])
# => proposal weight : -1.79763925075531, model weight : -14.463062286376953, sample : tensor([ 2.1683, -1.3781])
# => proposal weight : -1.2094897031784058, model weight : -13.785636901855469, sample : tensor([ 2.2229, -1.4029])
# => proposal weight : 0.07692855596542358, model weight : -13.176267623901367, sample : tensor([ 2.3367, -0.8128])
# => proposal weight : -0.49534785747528076, model weight : -14.638620376586914, sample : tensor([ 2.3692, -0.5196])
# => proposal weight : 0.054517269134521484, model weight : -12.862245559692383, sample : tensor([ 2.1042, -0.0112])
# => proposal weight : -1.1632477045059204, model weight : -14.8604154586792, sample : tensor([ 2.6542, -2.0806])
# => proposal weight : -0.7019672393798828, model weight : -14.926684379577637, sample : tensor([ 2.4886, -1.0063])
# => proposal weight : -1.4067857265472412, model weight : -14.463196754455566, sample : tensor([1.8547, 1.1546])
# => proposal weight : 0.1441667079925537, model weight : -12.968557357788086, sample : tensor([ 2.2098, -0.3376])
# => proposal weight : -0.5687528848648071, model weight : -13.089272499084473, sample : tensor([ 2.2306, -1.2076])
# => proposal weight : -0.01856207847595215, model weight : -13.051411628723145, sample : tensor([ 2.3855, -1.1954])
# => proposal weight : -0.03532952070236206, model weight : -13.545042037963867, sample : tensor([ 2.3407, -0.6855])
# => proposal weight : -0.5831183195114136, model weight : -14.229368209838867, sample : tensor([ 2.5448, -1.5485])
# => proposal weight : -0.7467725276947021, model weight : -15.147868156433105, sample : tensor([ 2.3368, -0.2793])
# => proposal weight : -1.431352138519287, model weight : -14.756921768188477, sample : tensor([1.9286, 1.0452])
# => proposal weight : -1.4961326122283936, model weight : -14.589372634887695, sample : tensor([1.8578, 1.1802])
# => proposal weight : 0.16914653778076172, model weight : -12.906217575073242, sample : tensor([ 2.2231, -0.4201])
# => proposal weight : -0.03723257780075073, model weight : -13.569470405578613, sample : tensor([ 2.2956, -0.4764])
# => proposal weight : -0.8917970657348633, model weight : -13.723482131958008, sample : tensor([ 2.4857, -1.9514])
# => proposal weight : -1.3340692520141602, model weight : -14.676996231079102, sample : tensor([1.9419, 0.9921])
# => proposal weight : -0.8385220766067505, model weight : -13.406644821166992, sample : tensor([ 2.2777, -1.4555])
# => proposal weight : 0.03644782304763794, model weight : -13.268482208251953, sample : tensor([ 2.2087, -0.2190])
# => proposal weight : -0.7592666149139404, model weight : -13.65333366394043, sample : tensor([ 2.4922, -1.8958])
# => proposal weight : -1.3858282566070557, model weight : -15.266422271728516, sample : tensor([ 2.6932, -2.1796])
# => proposal weight : -1.1529258489608765, model weight : -15.790404319763184, sample : tensor([ 2.5493, -1.1128])
# => proposal weight : -0.7594538927078247, model weight : -13.448174476623535, sample : tensor([1.8487, 0.7669])
# => proposal weight : -1.4293553829193115, model weight : -13.818102836608887, sample : tensor([ 1.9031, -0.1541])
# => proposal weight : -1.240459680557251, model weight : -15.067407608032227, sample : tensor([2.0607, 0.7154])
# => proposal weight : -0.2733633518218994, model weight : -14.14246654510498, sample : tensor([ 2.3510, -0.5576])
# => proposal weight : -0.20601773262023926, model weight : -13.399212837219238, sample : tensor([ 2.4517, -1.3908])
# => proposal weight : 0.18530893325805664, model weight : -12.701397895812988, sample : tensor([ 2.2649, -0.7473])
# => proposal weight : -0.5433796644210815, model weight : -13.247530937194824, sample : tensor([ 2.3887, -1.6225])
# => proposal weight : -2.364572525024414, model weight : -14.907658576965332, sample : tensor([1.8046, 0.0275])
# => proposal weight : 0.16719573736190796, model weight : -12.927900314331055, sample : tensor([ 2.2773, -0.6480])
# => proposal weight : -1.3590315580368042, model weight : -15.581782341003418, sample : tensor([2.1320, 0.5669])
# => proposal weight : -1.3074525594711304, model weight : -13.793341636657715, sample : tensor([ 2.0704, -0.8703])
# => proposal weight : -0.2627596855163574, model weight : -12.67867660522461, sample : tensor([ 2.0467, -0.3114])
# => proposal weight : -0.06318295001983643, model weight : -12.69861125946045, sample : tensor([2.0308, 0.0621])
# => proposal weight : -2.3746514320373535, model weight : -15.150394439697266, sample : tensor([ 2.5895, -2.6015])
# => proposal weight : -0.7633575201034546, model weight : -15.159180641174316, sample : tensor([ 2.4476, -0.7586])
# => proposal weight : -3.135928153991699, model weight : -19.644067764282227, sample : tensor([ 2.6267, -0.8667])
# ...
# => proposal weight : -0.11629056930541992, model weight : -12.6471586227417, sample : tensor([ 2.0244, -0.0268])
# => proposal weight : -1.9047837257385254, model weight : -14.843194961547852, sample : tensor([1.6361, 1.2109])
# => proposal weight : -0.630010724067688, model weight : -13.691610336303711, sample : tensor([ 2.5152, -1.8289])
# => proposal weight : -0.8965008854866028, model weight : -15.461932182312012, sample : tensor([ 2.4359, -0.6444])
# => proposal weight : -0.008606791496276855, model weight : -13.27921199798584, sample : tensor([ 2.1710, -0.0745])
# => proposal weight : -1.352290153503418, model weight : -14.052865982055664, sample : tensor([ 2.4512, -2.0576])
# => proposal weight : -2.068227529525757, model weight : -15.029485702514648, sample : tensor([1.6265, 1.1251])
# => proposal weight : 0.19102132320404053, model weight : -12.733362197875977, sample : tensor([ 2.1936, -0.3947])
# => proposal weight : -1.3910472393035889, model weight : -15.694804191589355, sample : tensor([ 2.6843, -1.9037])
# => proposal weight : -0.16909253597259521, model weight : -12.65873908996582, sample : tensor([ 2.0171, -0.0513])
# => proposal weight : -1.899182915687561, model weight : -14.707860946655273, sample : tensor([ 2.5659, -2.4337])
# => proposal weight : -0.12118834257125854, model weight : -12.616300582885742, sample : tensor([ 2.1644, -0.7487])
# => proposal weight : -0.6278759837150574, model weight : -14.921533584594727, sample : tensor([ 2.3855, -0.5300])
# => proposal weight : 0.018823325634002686, model weight : -12.521297454833984, sample : tensor([ 2.1501, -0.5822])
# => proposal weight : -0.48760759830474854, model weight : -14.621201515197754, sample : tensor([ 2.3711, -0.5320])
# => proposal weight : -0.5734961032867432, model weight : -14.787124633789062, sample : tensor([ 2.4090, -0.6631])
# => proposal weight : 0.10904592275619507, model weight : -13.135306358337402, sample : tensor([ 2.2452, -0.4124])
# => proposal weight : -0.9671921730041504, model weight : -13.465360641479492, sample : tensor([1.8250, 0.5215])
# => proposal weight : -0.5918911695480347, model weight : -13.108388900756836, sample : tensor([1.8879, 0.4326])
# => proposal weight : 0.057398200035095215, model weight : -13.064456939697266, sample : tensor([ 2.3612, -1.0118])
# => proposal weight : -0.4438294768333435, model weight : -12.849937438964844, sample : tensor([ 2.0913, -0.6267])
# => proposal weight : 0.10566580295562744, model weight : -13.156437873840332, sample : tensor([ 2.2562, -0.4506])
# => proposal weight : 0.12671291828155518, model weight : -13.095829963684082, sample : tensor([ 2.2680, -0.5256])
# => proposal weight : -3.6304545402526855, model weight : -19.623458862304688, sample : tensor([ 3.0045, -3.0213])
# => proposal weight : -0.27294039726257324, model weight : -13.102542877197266, sample : tensor([1.9859, 0.4133])
# => proposal weight : -0.9036304950714111, model weight : -15.014406204223633, sample : tensor([2.1743, 0.3204])
# => proposal weight : -0.9782930612564087, model weight : -14.13520336151123, sample : tensor([ 2.5772, -2.0719])
# => proposal weight : -3.877228260040283, model weight : -18.30927848815918, sample : tensor([2.0153, 1.3340])
# => proposal weight : -0.4095339775085449, model weight : -14.309273719787598, sample : tensor([ 2.2399, -0.0625])
# => proposal weight : -1.9946223497390747, model weight : -14.705873489379883, sample : tensor([ 2.1686, -1.4277])
# => proposal weight : -0.3101353645324707, model weight : -13.612404823303223, sample : tensor([2.0847, 0.3177])
# => proposal weight : -0.6958150267601013, model weight : -13.065067291259766, sample : tensor([ 2.0254, -0.4483])
# => proposal weight : -5.303922176361084, model weight : -18.764633178710938, sample : tensor([ 2.9575, -3.7369])
# => proposal weight : -1.9858258962631226, model weight : -15.807202339172363, sample : tensor([ 2.7605, -2.5909])
# => proposal weight : -0.7799148559570312, model weight : -13.144731521606445, sample : tensor([ 1.9314, -0.0155])
# => proposal weight : -0.07428610324859619, model weight : -13.633401870727539, sample : tensor([ 2.2635, -0.3232])
# => proposal weight : -0.08897054195404053, model weight : -12.7925386428833, sample : tensor([2.0230, 0.1578])
# => proposal weight : 0.039366722106933594, model weight : -13.15634822845459, sample : tensor([ 2.1692, -0.1101])
# => proposal weight : -1.4819692373275757, model weight : -13.884724617004395, sample : tensor([1.8607, 0.0395])
# => proposal weight : -0.1821281909942627, model weight : -12.702940940856934, sample : tensor([2.0011, 0.0536])
# => proposal weight : -2.300945281982422, model weight : -15.291972160339355, sample : tensor([1.7599, 1.5506])
# => proposal weight : 0.12841153144836426, model weight : -12.762137413024902, sample : tensor([ 2.1356, -0.1653])
# => proposal weight : -0.2101718783378601, model weight : -12.669516563415527, sample : tensor([ 2.1402, -0.7070])
# => proposal weight : -1.679073452949524, model weight : -14.727724075317383, sample : tensor([1.8261, 1.2828])
# => proposal weight : -1.265209674835205, model weight : -15.804290771484375, sample : tensor([ 2.6154, -1.4553])
# => proposal weight : -1.4418836832046509, model weight : -15.292295455932617, sample : tensor([ 2.7000, -2.2354])
# => proposal weight : -0.5741618275642395, model weight : -12.954841613769531, sample : tensor([ 2.0512, -0.5109])
# => proposal weight : -0.27053773403167725, model weight : -14.00482177734375, sample : tensor([ 2.2303, -0.0954])
# => proposal weight : -0.3836768865585327, model weight : -13.407995223999023, sample : tensor([ 2.4693, -1.6234])
# => proposal weight : -0.9604479074478149, model weight : -15.103194236755371, sample : tensor([2.1722, 0.3441])
# => proposal weight : -2.25663161277771, model weight : -15.002495765686035, sample : tensor([ 2.2940, -1.8879])
# => proposal weight : 0.154299795627594, model weight : -12.817709922790527, sample : tensor([ 2.3020, -0.8495])
# => proposal weight : -0.22185218334197998, model weight : -12.866146087646484, sample : tensor([ 2.3111, -1.2787])
# => proposal weight : -0.21381783485412598, model weight : -12.6434326171875, sample : tensor([ 2.0569, -0.3281])
# => proposal weight : -0.28044700622558594, model weight : -13.102296829223633, sample : tensor([1.9827, 0.4201])
# => proposal weight : 0.06635481119155884, model weight : -13.219118118286133, sample : tensor([ 2.2222, -0.2884])
# => proposal weight : -0.764142632484436, model weight : -14.855894088745117, sample : tensor([ 2.5455, -1.3225])
# => proposal weight : -5.007664680480957, model weight : -20.283329010009766, sample : tensor([ 3.0882, -3.7417])
# => proposal weight : -0.9057236909866333, model weight : -14.267265319824219, sample : tensor([ 2.5946, -1.9936])
# => proposal weight : -0.25831151008605957, model weight : -13.46994686126709, sample : tensor([2.0743, 0.3091])
# => proposal weight : -1.9030652046203613, model weight : -14.864078521728516, sample : tensor([1.6338, 1.3723])
# => proposal weight : 0.05453145503997803, model weight : -12.871788024902344, sample : tensor([ 2.1060, -0.0123])
# => proposal weight : -0.16543138027191162, model weight : -12.713088035583496, sample : tensor([2.0015, 0.0848])
# => proposal weight : 0.15733706951141357, model weight : -12.679338455200195, sample : tensor([ 2.1466, -0.2546])
# => proposal weight : -0.45431673526763916, model weight : -13.335004806518555, sample : tensor([ 2.4479, -1.6689])
# => proposal weight : -0.29199308156967163, model weight : -12.703285217285156, sample : tensor([ 2.0299, -0.2440])
# => proposal weight : -0.5212854146957397, model weight : -13.506033897399902, sample : tensor([ 2.4839, -1.7414])
# => proposal weight : -0.24884319305419922, model weight : -13.865545272827148, sample : tensor([ 2.4444, -1.0921])
# => proposal weight : -0.10614943504333496, model weight : -13.455376625061035, sample : tensor([ 2.4206, -1.1362])
# => proposal weight : 0.18641847372055054, model weight : -12.603696823120117, sample : tensor([ 2.2311, -0.6757])
# => proposal weight : -1.0909210443496704, model weight : -14.05819320678711, sample : tensor([ 2.5495, -2.1198])
# => proposal weight : -2.2596726417541504, model weight : -15.35893726348877, sample : tensor([1.8071, 1.4696])
# => proposal weight : -0.04054725170135498, model weight : -13.007689476013184, sample : tensor([ 2.3834, -1.2423])
# => proposal weight : -0.7949501276016235, model weight : -13.457892417907715, sample : tensor([ 2.3839, -1.7193])
# => proposal weight : -0.11590695381164551, model weight : -12.693825721740723, sample : tensor([ 2.2450, -1.0293])
# => proposal weight : 0.19749915599822998, model weight : -12.757147789001465, sample : tensor([ 2.2526, -0.6364])
# => proposal weight : -1.2641264200210571, model weight : -14.958904266357422, sample : tensor([2.0295, 0.7937])
# => proposal weight : -2.047793388366699, model weight : -15.03213119506836, sample : tensor([1.6257, 1.5171])
# => proposal weight : -0.18027812242507935, model weight : -13.81882095336914, sample : tensor([ 2.4055, -0.9059])
# => proposal weight : 0.013031482696533203, model weight : -13.436043739318848, sample : tensor([ 2.2894, -0.4924])
# => proposal weight : -1.4093085527420044, model weight : -14.73862075805664, sample : tensor([ 2.6510, -2.3256])
# => proposal weight : 0.15956604480743408, model weight : -12.54131031036377, sample : tensor([ 2.1604, -0.4350])
# => proposal weight : -1.2017831802368164, model weight : -13.603362083435059, sample : tensor([1.8547, 0.1906])
# => proposal weight : 0.07243835926055908, model weight : -12.59814453125, sample : tensor([ 2.0906, -0.1549])
# => proposal weight : -0.22514313459396362, model weight : -13.994778633117676, sample : tensor([ 2.3827, -0.7412])
# => proposal weight : 0.07661968469619751, model weight : -13.250913619995117, sample : tensor([ 2.2998, -0.6045])
# => proposal weight : -2.6477785110473633, model weight : -15.245308876037598, sample : tensor([ 1.8014, -0.0359])
# => proposal weight : -0.4423336386680603, model weight : -14.502120971679688, sample : tensor([ 2.3968, -0.6737])
# => proposal weight : -0.6090564727783203, model weight : -14.263429641723633, sample : tensor([2.1120, 0.3876])
# => proposal weight : -0.23910033702850342, model weight : -12.756340980529785, sample : tensor([1.9821, 0.1222])
# => proposal weight : -2.9795970916748047, model weight : -15.946876525878906, sample : tensor([ 2.1309, -1.5104])
# => proposal weight : -0.028135359287261963, model weight : -12.535847663879395, sample : tensor([ 2.0993, -0.3860])
# => proposal weight : -0.9113459587097168, model weight : -15.376437187194824, sample : tensor([ 2.5026, -0.9717])
# => proposal weight : 0.08942890167236328, model weight : -12.886286735534668, sample : tensor([ 2.1323, -0.0904])
# => proposal weight : -0.14227592945098877, model weight : -13.534010887145996, sample : tensor([2.1568, 0.0539])
# => proposal weight : -2.5066380500793457, model weight : -17.046947479248047, sample : tensor([ 2.8542, -2.7377])
# => proposal weight : 0.09935712814331055, model weight : -12.586112976074219, sample : tensor([ 2.1056, -0.2054])
# => proposal weight : -0.8392850756645203, model weight : -13.265103340148926, sample : tensor([ 2.0895, -0.7886])
# => proposal weight : -2.09431529045105, model weight : -14.773675918579102, sample : tensor([ 2.4295, -2.2084])
# => proposal weight : 0.16800183057785034, model weight : -12.92928409576416, sample : tensor([ 2.2741, -0.6322])
# => proposal weight : 0.04391449689865112, model weight : -13.332878112792969, sample : tensor([ 2.3215, -0.6724])
# => proposal weight : -1.359108805656433, model weight : -14.066422462463379, sample : tensor([1.7283, 0.9598])
# => proposal weight : -1.5193003416061401, model weight : -14.14323902130127, sample : tensor([ 2.2138, -1.4607])
# => proposal weight : -0.9472626447677612, model weight : -13.526883125305176, sample : tensor([1.8087, 0.6972])
# => proposal weight : -0.26658570766448975, model weight : -12.680869102478027, sample : tensor([ 2.0549, -0.3558])
# => proposal weight : -1.824202537536621, model weight : -17.299583435058594, sample : tensor([ 2.4314, -0.3237])
# => proposal weight : -0.8596986532211304, model weight : -13.421934127807617, sample : tensor([ 2.2672, -1.4311])
# => proposal weight : -3.416801929473877, model weight : -17.77739906311035, sample : tensor([2.0197, 1.2538])
# => proposal weight : -0.7379211187362671, model weight : -13.151215553283691, sample : tensor([1.8945, 0.2272])
# => proposal weight : -0.12093579769134521, model weight : -12.657329559326172, sample : tensor([ 2.0209, -0.0060])
# => proposal weight : -0.30367493629455566, model weight : -13.764608383178711, sample : tensor([ 2.4795, -1.3440])
# => proposal weight : -1.52833890914917, model weight : -14.19050407409668, sample : tensor([ 2.4050, -2.0061])
# => proposal weight : -0.15044748783111572, model weight : -12.669862747192383, sample : tensor([ 2.1995, -0.8985])
# => proposal weight : -0.15311670303344727, model weight : -13.702251434326172, sample : tensor([ 2.2074, -0.0846])
# => proposal weight : -1.826168179512024, model weight : -14.495339393615723, sample : tensor([ 2.3842, -2.0333])
# => proposal weight : -0.7345107197761536, model weight : -13.090288162231445, sample : tensor([ 1.9774, -0.2334])
# => proposal weight : -0.07670187950134277, model weight : -13.275392532348633, sample : tensor([ 2.4143, -1.2066])
# => proposal weight : -2.819340705871582, model weight : -15.510747909545898, sample : tensor([1.7293, 0.2675])
# => proposal weight : 0.024409055709838867, model weight : -12.553435325622559, sample : tensor([ 2.0821, -0.2151])
# => proposal weight : -0.32398736476898193, model weight : -13.177326202392578, sample : tensor([1.9777, 0.4655])
# => proposal weight : 0.12028747797012329, model weight : -12.904862403869629, sample : tensor([ 2.3268, -0.9234])
# => proposal weight : 0.0635913610458374, model weight : -12.510844230651855, sample : tensor([ 2.1232, -0.4045])
# => proposal weight : -2.6178712844848633, model weight : -15.630974769592285, sample : tensor([1.5918, 1.8019])
# => proposal weight : -1.8948471546173096, model weight : -14.924386978149414, sample : tensor([1.8016, 1.3814])
# => proposal weight : -5.127345561981201, model weight : -18.918609619140625, sample : tensor([1.9004, 1.7620])
# => proposal weight : -0.4229336977005005, model weight : -14.377204895019531, sample : tensor([ 2.2586, -0.1202])
# => proposal weight : -0.6697158813476562, model weight : -13.03524112701416, sample : tensor([ 1.9529, -0.0711])
# => proposal weight : -1.1880865097045898, model weight : -14.488311767578125, sample : tensor([1.9462, 0.9388])
# => proposal weight : -0.814766526222229, model weight : -14.2393217086792, sample : tensor([2.0226, 0.6658])
# => proposal weight : 0.1672322154045105, model weight : -12.937808990478516, sample : tensor([ 2.2425, -0.4863])
# => proposal weight : -0.44079434871673584, model weight : -13.27720832824707, sample : tensor([1.9472, 0.5719])
# => proposal weight : 0.15736395120620728, model weight : -12.52835464477539, sample : tensor([ 2.1774, -0.5285])
# => proposal weight : 0.007689237594604492, model weight : -13.088746070861816, sample : tensor([ 2.3813, -1.1253])
# => proposal weight : -0.7193197011947632, model weight : -14.01912784576416, sample : tensor([ 2.5610, -1.8631])
# => proposal weight : -2.0681371688842773, model weight : -14.594435691833496, sample : tensor([ 1.9330, -0.4966])
# => proposal weight : -3.5881221294403076, model weight : -16.420194625854492, sample : tensor([1.6422, 2.0077])
# => proposal weight : -1.5245755910873413, model weight : -15.708839416503906, sample : tensor([ 2.7164, -2.1365])
# => proposal weight : -1.9627457857131958, model weight : -14.887467384338379, sample : tensor([1.7365, 1.4789])
# => proposal weight : -0.04404062032699585, model weight : -13.549432754516602, sample : tensor([ 2.2546, -0.3118])
# => proposal weight : -0.8516772985458374, model weight : -13.550209999084473, sample : tensor([ 2.4146, -1.8079])
# Sample size: 3000
# Effective sample size: tensor(2394.1829)
# Fractional sample size: tensor(0.7981)
# Sum of weights: tensor(1.)

# %%
df1 = pd.DataFrame(proposal_samples, columns = ["slope", "bias"])
df2 = pd.DataFrame(samples, columns = ["slope", "bias"])
samples_dict = {"proposal" : {"slope" : df1["slope"].to_numpy(), "bias" : df1["bias"].to_numpy()},
                "posterior" :{"slope" : df2["slope"].to_numpy(), "bias" : df2["bias"].to_numpy()}}

# %%
# Make a triangle plot to see slope and bias distributions and correlations
def triangle_plot(samples_dict, mu=None, cov=None, **kwargs):
    plt.subplots(2, 2, **kwargs)
    plt.subplot(2, 2, 1)
    for name, samples in samples_dict.items():
        plt.hist(samples['bias'], alpha=0.7, density=True, bins='auto', label=name)
    if mu is not None and cov is not None:
        x, f = get_distribution(plt, mu[0], np.sqrt(cov[0, 0]))
        plt.plot(x, f, color='black', label='analytical')
    plt.gca().set_xticklabels([])
    plt.yticks([])
    plt.legend(prop={'size': 12})
    plt.subplot(2, 2, 4)
    for name, samples in samples_dict.items():
        plt.hist(samples['slope'], alpha=0.7, density=True, bins='auto', label=name)
    if mu is not None and cov is not None:
        x, f = get_distribution(plt, mu[1], np.sqrt(cov[1, 1]))
        plt.plot(x, f, color='black', label='analytical')
    plt.xlabel('slope')
    plt.yticks([])
    plt.subplot(2, 2, 3)
    for name, samples in samples_dict.items():
        plt.scatter(samples['bias'], samples['slope'], alpha=0.5, s=5., label=name)
    if mu is not None and cov is not None:
        X, Y, Z = get_contours(plt, mu, cov)
        plt.contour(X, Y, Z, colors='black', alpha=0.9, levels=3)
    plt.xlabel('bias')
    plt.ylabel('slope')
    plt.subplot(2, 2, 2).axis('off')
    plt.tight_layout()
    plt.show()

# Plot the learning curves to see how training is progressing
def plot_learning_curve(training_logfile, **kwargs):
    data = np.loadtxt(training_logfile, skiprows=1, delimiter=',', converters={8: lambda _: 0.})
    plt.figure(**kwargs)
    plt.plot(data[:, 1], data[:, 3], label='training')
    plt.xlabel('Training iteration')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Analytical expression for the posterior covariance
def analytical_covariance(x, sigma, alpha):
    cov1 = np.identity(2)*(sigma/alpha)**2
    x0_sum = len(x)
    x1_sum = np.sum(x)
    x2_sum = np.sum(x**2)
    cov2 = np.array([
        [x0_sum, x1_sum],
        [x1_sum, x2_sum],
    ])
    cov = (1./sigma**2)*(cov1+cov2)
    cov = np.linalg.inv(cov)
    return cov

# Analytical expression for the posterior mean
def analytical_mean(x, y, sigma, alpha):
    xy_sum = np.sum(x*y)
    y_sum = np.sum(y)
    vec = np.array([y_sum, xy_sum])
    cov = analytical_covariance(x, sigma, alpha)
    mu = np.matmul(cov, vec)/sigma**2
    return mu

# Distribution for 1D marginal posteriors
def get_distribution(plt, mu, sig, N=200):
    xlim = plt.gca().get_xlim()
    x = np.linspace(xlim[0], xlim[1], N)
    rv = norm(mu, sig)
    f = rv.pdf(x)
    return x, f

# Contours for 2D posterior distributions
def get_contours(plt, mu, cov, N=200):
    xlim = plt.gca().get_xlim(); ylim = plt.gca().get_ylim()
    X = np.linspace(xlim[0], xlim[1], N)
    Y = np.linspace(ylim[0], ylim[1], N)
    X, Y = np.meshgrid(X, Y); pos = np.dstack((X, Y))
    rv = multivariate_normal(mu, cov)
    Z = rv.pdf(pos)
    return X, Y, Z

# %%
x = np.array([1., 2., 3., 4., 5., 6.])
sigma = 1.0  # Likelihood error
alpha = 10.0 # Prior scale
obs_np = observed.numpy()
mu = analytical_mean(np.array(x), np.sort(obs_np), sigma, alpha)
cov = analytical_covariance(np.array(x), sigma, alpha)
print(mu, " +- ", np.sqrt(cov.diagonal()))
print(cov)
# Out:
# [-0.50466187  2.14919125]  +-  [0.92672928 0.23814725]
# [[ 0.85882716 -0.19816911]
#  [-0.19816911  0.05671411]]

# %%
triangle_plot(samples_dict, mu, cov, figsize=(8,8))
plt.save()

# %%
observed = []
for var in model.topological():
    if var in model.Graph["Y"].keys():
        observed.append(tc.tensor(model.Graph["Y"][var]).float())

observed = tc.stack(observed)

observed_test1 = np.random.normal(1 * x + 3, scale = sigma)
observed_test1 = tc.tensor(observed_test1[observed.argsort().argsort()]).float()

observed_test2 = np.random.normal(5 * x + 8, scale = sigma)
observed_test2 = tc.tensor(observed_test2[observed.argsort().argsort()]).float()

observed_test3 = np.random.normal(9 * x + 13, scale = sigma)
observed_test3 = tc.tensor(observed_test3[observed.argsort().argsort()]).float()

# %%
def plot_proposal_by_epochs(epochs : int, observed : tc.Tensor, model, num_samples = 2000, **kwargs):
    
    latents = [var for var in model.topological() if var.startswith("sample")]
    fig, axs = plt.subplots(2, epochs, **kwargs)

    x = np.array([1., 2., 3., 4., 5., 6.])
    mu = analytical_mean(np.array(x), np.sort(observed), sigma, alpha)
    cov = analytical_covariance(np.array(x), sigma, alpha)

    for i, latent in enumerate(latents):
        for epoch in range(epochs):
            with open(run + "proposal_epoch{}.pkl".format(epoch), "rb") as f:
                proposal = pickle.load(f)
            
            proposal_samples = []
            for _ in range(num_samples):
                sample = proposal.sample(y = observed)[latent]
                proposal_samples.append(sample)

            proposal_samples = tc.stack(proposal_samples).numpy()
            axs[i,epoch].hist(proposal_samples, bins="auto", label="Epoch {}".format(epoch + 1), density=True)
            xlim = axs[i,epoch].get_xlim()
            x = np.linspace(xlim[0], xlim[1], 5000)
            rv = norm(mu[1-i], np.sqrt(cov[1-i,1-i]))
            f = rv.pdf(x)
            
            axs[i,epoch].plot(x, f, label="Analytical posterior")

            axs[i,epoch].legend(loc="upper right", prop = {"size" : 12})
    
    axs[0,0].set_ylabel("slope")
    axs[1,0].set_ylabel("bias")

# %%
plot_proposal_by_epochs(epochs=7, observed=observed, model=model, num_samples=3000, figsize=(26,10))
print(observed.sort())
# y = 2x + 0
# Out:
# torch.return_types.sort(
# values=tensor([ 2.0500,  3.9400,  5.9000,  8.0300, 10.1000, 11.8600]),
# indices=tensor([5, 3, 0, 4, 2, 1]))

# %%
plot_proposal_by_epochs(epochs=7, observed=observed_test1, model=model, figsize=(20,8))
print(observed_test1.sort())
# y = x + 3
# Out:
# torch.return_types.sort(
# values=tensor([3.9494, 4.9548, 5.8313, 7.0786, 8.1524, 9.1087]),
# indices=tensor([5, 3, 0, 4, 2, 1]))

# %%
plot_proposal_by_epochs(epochs=7, observed=observed_test2, model=model, figsize=(20,8))
# y = 5x + 8

# %%
plot_proposal_by_epochs(epochs=7, observed=observed_test3, model=model, figsize=(20,8))
# y = 9x + 13

# %%
def plot_losses(**kwargs):
    losses = tc.load(run + "losses.pt")
    fig, axs = plt.subplots(1, len(losses), **kwargs)
    for i, loss in enumerate(losses):
        axs[i].plot(loss, label="epoch {}".format(i))
        axs[i].legend()
    return

# %%
plot_losses(figsize=(20,4))
