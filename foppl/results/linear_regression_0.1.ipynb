# %%
import torch as tc
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from scipy.stats import norm, multivariate_normal
sys.path.append(r'../') #path to folder where file that stored the results is located
from utils import calculate_effective_sample_size

plt.rc('font', family='serif', size=14)
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

# %%
run = "./run_2022-12-04_11-36-53/"

# %%
with open(run + "graphical_model.pkl", "rb") as f:
    model = pickle.load(f)

observed = []
observed_dict = {}
for var in model.topological():
    if var in model.Graph["Y"].keys():
        observed.append(tc.tensor(model.Graph["Y"][var]).float())
        observed_dict.update({var : tc.tensor(model.Graph["Y"][var]).float()})

observed = tc.stack(observed)
print("observed : {}".format(observed))
# Out:
# observed : tensor([ 5.9000, 11.8600, 10.1000,  3.9400,  8.0300,  2.0500])

# %%
def get_samples(epoch, observed, observed_dict, num_samples=2000):
    proposal_samples = []
    proposal_weights = []
    model_weights = []
    weights = []
    with open(run + "proposal_epoch{}.pkl".format(epoch), "rb") as f:
        proposal = pickle.load(f)
    with open(run + "/model.pkl", "rb") as f:
        model = pickle.load(f)


    for i in range(num_samples):
        sample_dict = proposal.sample(y = observed)
        sample_tensor = tc.stack([sample_dict[latent] for latent in model.latent_ordered_vars]) #topological order
        proposal_samples.append(sample_tensor) #sample in the topological order
        model_weights.append(model.log_prob({**sample_dict, **observed_dict}).detach().clone())
        proposal_weights.append(proposal.log_prob(sample_tensor, observed).detach().clone())
        weights.append(tc.exp(model_weights[i] - proposal_weights[i]))
        print("=> proposal weight : {}, model weight : {}, sample : {}".format(proposal_weights[i], model_weights[i], sample_tensor))

    proposal_samples = tc.stack(proposal_samples)
    proposal_weights = tc.stack(proposal_weights)
    model_weights = tc.stack(model_weights)
    calculate_effective_sample_size(tc.stack(weights), verbose=True)
    weights = tc.stack(weights).numpy()
    weights /= weights.sum()
    

    idx = np.random.choice(np.arange(len(weights)), size=len(weights), p=weights)
    resamples = proposal_samples[idx]
    return proposal_samples, resamples

# %%
proposal_samples, samples = get_samples(epoch = 7, observed = observed, observed_dict=observed_dict, num_samples=3000)
proposal_samples = proposal_samples.numpy()
samples = samples.numpy()
# Out:
# => proposal weight : 2.759751081466675, model weight : -24.344898223876953, sample : tensor([2.0464, 0.0842])
# => proposal weight : 3.135213851928711, model weight : -1.1193259954452515, sample : tensor([1.9605, 0.1318])
# => proposal weight : 3.428061008453369, model weight : -2.2592172622680664, sample : tensor([ 2.0212, -0.0328])
# => proposal weight : 1.0943111181259155, model weight : -37.65652084350586, sample : tensor([ 2.0979, -0.0616])
# => proposal weight : 3.025538444519043, model weight : -5.2012810707092285, sample : tensor([1.9782, 0.1827])
# => proposal weight : 2.4505391120910645, model weight : -22.200836181640625, sample : tensor([ 2.0698, -0.0307])
# => proposal weight : 3.62608003616333, model weight : -1.1026417016983032, sample : tensor([2.0054, 0.0065])
# => proposal weight : 3.484058380126953, model weight : -0.30608606338500977, sample : tensor([1.9861, 0.0255])
# => proposal weight : 3.676569938659668, model weight : -5.843944072723389, sample : tensor([2.0093, 0.0796])
# => proposal weight : 1.920722246170044, model weight : -3.0950498580932617, sample : tensor([1.9339, 0.2212])
# => proposal weight : 3.685340404510498, model weight : -3.4685258865356445, sample : tensor([2.0158, 0.0182])
# => proposal weight : 0.30370235443115234, model weight : -60.95793151855469, sample : tensor([2.0863, 0.0968])
# => proposal weight : 2.7387819290161133, model weight : -21.836593627929688, sample : tensor([2.0287, 0.1394])
# => proposal weight : 3.414729118347168, model weight : -4.959227561950684, sample : tensor([1.9897, 0.1409])
# => proposal weight : 3.718003273010254, model weight : -3.097886562347412, sample : tensor([1.9990, 0.0791])
# => proposal weight : 3.6955690383911133, model weight : -1.693956971168518, sample : tensor([2.0061, 0.0216])
# => proposal weight : 3.4965434074401855, model weight : -8.254610061645508, sample : tensor([2.0331, 0.0099])
# => proposal weight : 3.6562752723693848, model weight : -0.7134004831314087, sample : tensor([1.9892, 0.0552])
# => proposal weight : 1.8715240955352783, model weight : -21.01771354675293, sample : tensor([2.0017, 0.2362])
# => proposal weight : 3.1903553009033203, model weight : -13.620025634765625, sample : tensor([2.0152, 0.1331])
# => proposal weight : 1.8489112854003906, model weight : -9.594145774841309, sample : tensor([1.9683, 0.2629])
# => proposal weight : 2.7732529640197754, model weight : -1.097109317779541, sample : tensor([ 2.0004, -0.0703])
# => proposal weight : 2.533738374710083, model weight : -28.034103393554688, sample : tensor([2.0517, 0.0846])
# => proposal weight : 3.698333740234375, model weight : -3.389565944671631, sample : tensor([1.9983, 0.0868])
# => proposal weight : 2.6605019569396973, model weight : -2.18206787109375, sample : tensor([1.9530, 0.1920])
# => proposal weight : 3.6988167762756348, model weight : -1.0483108758926392, sample : tensor([1.9959, 0.0439])
# => proposal weight : 2.9442882537841797, model weight : -0.6923816204071045, sample : tensor([ 2.0069, -0.0675])
# => proposal weight : 3.168638229370117, model weight : -1.2953015565872192, sample : tensor([1.9690, 0.0435])
# => proposal weight : 1.4973551034927368, model weight : -5.462769508361816, sample : tensor([1.9459, 0.2766])
# => proposal weight : 3.6877527236938477, model weight : -0.9197090864181519, sample : tensor([1.9951, 0.0423])
# => proposal weight : 2.019606113433838, model weight : -8.155440330505371, sample : tensor([1.9509, 0.0044])
# => proposal weight : 2.805166721343994, model weight : -16.910493850708008, sample : tensor([2.0128, 0.1676])
# => proposal weight : 3.473877429962158, model weight : -0.29195404052734375, sample : tensor([1.9892, 0.0150])
# => proposal weight : 3.669517993927002, model weight : -1.426883339881897, sample : tensor([1.9888, 0.0809])
# => proposal weight : 3.3124356269836426, model weight : -0.7642883062362671, sample : tensor([1.9683, 0.0780])
# => proposal weight : 3.005988121032715, model weight : -1.3345428705215454, sample : tensor([1.9557, 0.1349])
# => proposal weight : 1.6404505968093872, model weight : -10.649096488952637, sample : tensor([1.9680, 0.2738])
# => proposal weight : 2.8258423805236816, model weight : -2.2984604835510254, sample : tensor([1.9501, 0.1102])
# => proposal weight : 2.3849127292633057, model weight : -15.039629936218262, sample : tensor([ 2.0682, -0.0811])
# => proposal weight : 1.2839839458465576, model weight : -37.15492630004883, sample : tensor([2.0321, 0.2109])
# => proposal weight : 3.422219753265381, model weight : -0.6971737146377563, sample : tensor([1.9718, 0.0978])
# => proposal weight : 0.4507012367248535, model weight : -20.47418785095215, sample : tensor([1.9166, 0.0453])
# => proposal weight : 3.658637523651123, model weight : -0.6814101934432983, sample : tensor([1.9940, 0.0368])
# => proposal weight : 3.6489291191101074, model weight : -7.133480548858643, sample : tensor([2.0202, 0.0515])
# => proposal weight : 1.05548095703125, model weight : -13.44096565246582, sample : tensor([ 1.9551, -0.0632])
# => proposal weight : 2.5449533462524414, model weight : -27.293973922729492, sample : tensor([2.0596, 0.0470])
# => proposal weight : 2.588352680206299, model weight : -2.3275303840637207, sample : tensor([1.9436, 0.1564])
# => proposal weight : 1.0947643518447876, model weight : -3.120274543762207, sample : tensor([ 2.0468, -0.1944])
# => proposal weight : 3.2322378158569336, model weight : -15.842050552368164, sample : tensor([2.0304, 0.0909])
# => proposal weight : 3.379500389099121, model weight : -0.47901034355163574, sample : tensor([ 2.0041, -0.0258])
# => proposal weight : 2.3597447872161865, model weight : -30.786468505859375, sample : tensor([2.0551, 0.0863])
# => proposal weight : 3.3448104858398438, model weight : -0.3798069953918457, sample : tensor([ 1.9909, -0.0055])
# => proposal weight : 2.4901998043060303, model weight : -25.473405838012695, sample : tensor([2.0668, 0.0049])
# => proposal weight : 2.553866386413574, model weight : -3.979888439178467, sample : tensor([ 2.0440, -0.1115])
# => proposal weight : 3.0998587608337402, model weight : -1.1807175874710083, sample : tensor([1.9594, 0.1362])
# => proposal weight : 3.4950804710388184, model weight : -4.649488925933838, sample : tensor([1.9917, 0.1295])
# => proposal weight : 3.5599584579467773, model weight : -1.0802360773086548, sample : tensor([ 2.0083, -0.0080])
# => proposal weight : 1.934625506401062, model weight : -1.9919116497039795, sample : tensor([ 2.0339, -0.1498])
# => proposal weight : 2.810697555541992, model weight : -2.463656425476074, sample : tensor([ 2.0334, -0.0942])
# => proposal weight : 2.8680949211120605, model weight : -20.47028350830078, sample : tensor([2.0292, 0.1284])
# => proposal weight : 3.394896984100342, model weight : -0.7563120126724243, sample : tensor([1.9706, 0.1037])
# => proposal weight : 3.2405128479003906, model weight : -3.535475730895996, sample : tensor([1.9777, 0.1599])
# => proposal weight : 0.37384116649627686, model weight : -49.297855377197266, sample : tensor([2.0427, 0.2248])
# => proposal weight : 3.3420372009277344, model weight : -0.6939603090286255, sample : tensor([1.9693, 0.0787])
# => proposal weight : 3.557401180267334, model weight : -4.988386631011963, sample : tensor([1.9961, 0.1184])
# => proposal weight : 3.0906224250793457, model weight : -15.136066436767578, sample : tensor([2.0170, 0.1384])
# => proposal weight : 3.106318473815918, model weight : -1.4115456342697144, sample : tensor([1.9621, 0.1505])
# => proposal weight : 2.8183846473693848, model weight : -8.898305892944336, sample : tensor([ 2.0529, -0.0736])
# => proposal weight : 2.8179519176483154, model weight : -20.842529296875, sample : tensor([2.0283, 0.1346])
# => proposal weight : 2.646531343460083, model weight : -2.763611316680908, sample : tensor([ 2.0371, -0.1065])
# => proposal weight : 3.38476824760437, model weight : -7.390151023864746, sample : tensor([1.9983, 0.1392])
# => proposal weight : 2.698965311050415, model weight : -24.549898147583008, sample : tensor([2.0400, 0.1114])
# => proposal weight : 2.1925652027130127, model weight : -16.305828094482422, sample : tensor([1.9952, 0.2278])
# => proposal weight : 3.3665542602539062, model weight : -0.4057431221008301, sample : tensor([1.9870, 0.0066])
# => proposal weight : 0.768271803855896, model weight : -4.914653301239014, sample : tensor([1.9260, 0.2970])
# => proposal weight : 1.6901140213012695, model weight : -6.831628322601318, sample : tensor([ 2.0627, -0.1588])
# => proposal weight : 2.7227087020874023, model weight : -1.7920171022415161, sample : tensor([1.9493, 0.1682])
# => proposal weight : 2.1290669441223145, model weight : -32.6004753112793, sample : tensor([2.0717, 0.0261])
# => proposal weight : 3.691378116607666, model weight : -1.7830697298049927, sample : tensor([2.0072, 0.0193])
# => proposal weight : 3.735661029815674, model weight : -2.070831298828125, sample : tensor([2.0038, 0.0403])
# => proposal weight : 2.7362184524536133, model weight : -4.634692668914795, sample : tensor([ 2.0440, -0.0963])
# => proposal weight : 2.5978658199310303, model weight : -4.40653657913208, sample : tensor([1.9539, 0.0419])
# => proposal weight : 3.0620718002319336, model weight : -1.2369805574417114, sample : tensor([1.9582, 0.1390])
# => proposal weight : 3.412929058074951, model weight : -12.629804611206055, sample : tensor([2.0278, 0.0751])
# => proposal weight : 1.9592158794403076, model weight : -8.780717849731445, sample : tensor([1.9426, 0.0337])
# => proposal weight : 3.2652697563171387, model weight : -4.885631561279297, sample : tensor([1.9841, 0.1591])
# => proposal weight : 1.395500659942627, model weight : -19.094585418701172, sample : tensor([ 2.0863, -0.1329])
# => proposal weight : 3.305586814880371, model weight : -4.086369037628174, sample : tensor([ 2.0319, -0.0444])
# => proposal weight : -1.091601848602295, model weight : -10.949958801269531, sample : tensor([ 2.0926, -0.2734])
# => proposal weight : 3.2468137741088867, model weight : -5.921594619750977, sample : tensor([1.9876, 0.1605])
# => proposal weight : 2.987478256225586, model weight : -14.190832138061523, sample : tensor([ 2.0543, -0.0245])
# => proposal weight : 3.7026424407958984, model weight : -2.4114112854003906, sample : tensor([1.9946, 0.0826])
# => proposal weight : 2.80340576171875, model weight : -1.908190131187439, sample : tensor([1.9553, 0.1793])
# => proposal weight : 3.0514676570892334, model weight : -4.047206401824951, sample : tensor([1.9742, 0.1789])
# => proposal weight : 3.731480121612549, model weight : -1.687120795249939, sample : tensor([1.9992, 0.0495])
# => proposal weight : 3.5448975563049316, model weight : -0.45768165588378906, sample : tensor([1.9803, 0.0655])
# => proposal weight : -0.37308478355407715, model weight : -26.142885208129883, sample : tensor([ 1.9312, -0.0548])
# => proposal weight : 1.4915125370025635, model weight : -6.298160552978516, sample : tensor([1.9192, 0.1900])
# => proposal weight : 1.127993106842041, model weight : -49.21260070800781, sample : tensor([2.0786, 0.0796])
# => proposal weight : 3.0463812351226807, model weight : -1.3785368204116821, sample : tensor([1.9566, 0.1136])
# => proposal weight : 3.5535130500793457, model weight : -2.3808822631835938, sample : tensor([1.9848, 0.1161])
# => proposal weight : -0.27311432361602783, model weight : -67.7884292602539, sample : tensor([2.0818, 0.1414])
# => proposal weight : 3.128304958343506, model weight : -6.0509209632873535, sample : tensor([ 2.0412, -0.0564])
# => proposal weight : 3.462252140045166, model weight : -0.5293304920196533, sample : tensor([1.9747, 0.0783])
# => proposal weight : 3.1194753646850586, model weight : -16.405363082885742, sample : tensor([2.0242, 0.1198])
# => proposal weight : 3.235130786895752, model weight : -2.761160373687744, sample : tensor([1.9740, 0.1573])
# => proposal weight : 3.3023858070373535, model weight : -7.9779229164123535, sample : tensor([ 2.0403, -0.0258])
# => proposal weight : 3.5208725929260254, model weight : -9.494020462036133, sample : tensor([2.0158, 0.0945])
# => proposal weight : 3.1956286430358887, model weight : -0.5904960632324219, sample : tensor([ 2.0088, -0.0495])
# => proposal weight : 2.8035824298858643, model weight : -19.612592697143555, sample : tensor([ 2.0597, -0.0044])
# => proposal weight : 3.031986713409424, model weight : -8.115012168884277, sample : tensor([1.9892, 0.1791])
# => proposal weight : 3.607081413269043, model weight : -0.6166659593582153, sample : tensor([1.9839, 0.0677])
# => proposal weight : 2.880377769470215, model weight : -8.8801851272583, sample : tensor([1.9878, 0.1918])
# => proposal weight : 2.0639257431030273, model weight : -20.37200355529785, sample : tensor([ 2.0775, -0.0799])
# => proposal weight : 2.529416799545288, model weight : -4.006341934204102, sample : tensor([1.9432, 0.1019])
# => proposal weight : 3.593557834625244, model weight : -5.646892070770264, sample : tensor([2.0258, 0.0086])
# => proposal weight : 2.650420904159546, model weight : -20.608671188354492, sample : tensor([ 2.0644, -0.0180])
# => proposal weight : 3.151409149169922, model weight : -1.0847448110580444, sample : tensor([1.9609, 0.1285])
# => proposal weight : 1.405781626701355, model weight : -29.237424850463867, sample : tensor([ 2.0921, -0.0848])
# => proposal weight : 2.394472360610962, model weight : -20.999969482421875, sample : tensor([ 2.0712, -0.0456])
# => proposal weight : 2.9087326526641846, model weight : -12.038657188415527, sample : tensor([ 2.0550, -0.0484])
# => proposal weight : 3.161759853363037, model weight : -0.6938674449920654, sample : tensor([ 1.9901, -0.0221])
# => proposal weight : 3.126206636428833, model weight : -15.887569427490234, sample : tensor([2.0486, 0.0149])
# => proposal weight : 2.4896838665008545, model weight : -28.671531677246094, sample : tensor([2.0512, 0.0903])
# => proposal weight : 3.372464179992676, model weight : -11.5159330368042, sample : tensor([2.0392, 0.0173])
# => proposal weight : 3.560397148132324, model weight : -7.562454700469971, sample : tensor([2.0082, 0.1042])
# => proposal weight : 3.3659117221832275, model weight : -3.669376850128174, sample : tensor([1.9825, 0.1465])
# => proposal weight : 3.387911796569824, model weight : -0.8856450319290161, sample : tensor([ 2.0113, -0.0330])
# => proposal weight : 3.015620470046997, model weight : -1.7453738451004028, sample : tensor([1.9570, 0.0899])
# => proposal weight : 3.486219882965088, model weight : -0.42487001419067383, sample : tensor([1.9780, 0.0608])
# => proposal weight : 3.061901092529297, model weight : -3.0003366470336914, sample : tensor([1.9698, 0.1742])
# => proposal weight : 2.1030120849609375, model weight : -1.8655920028686523, sample : tensor([ 2.0119, -0.1241])
# => proposal weight : 3.167121410369873, model weight : -5.332476615905762, sample : tensor([ 2.0386, -0.0553])
# => proposal weight : 3.596449375152588, model weight : -0.6901239156723022, sample : tensor([1.9825, 0.0754])
# => proposal weight : 3.314271926879883, model weight : -1.1807657480239868, sample : tensor([ 2.0162, -0.0446])
# => proposal weight : 3.516385078430176, model weight : -0.4086737632751465, sample : tensor([1.9797, 0.0597])
# => proposal weight : 3.6994285583496094, model weight : -5.505148410797119, sample : tensor([2.0160, 0.0483])
# => proposal weight : 1.808509111404419, model weight : -7.085867404937744, sample : tensor([1.9255, 0.1388])
# => proposal weight : 3.497279405593872, model weight : -4.010180950164795, sample : tensor([1.9891, 0.1294])
# => proposal weight : 3.6602087020874023, model weight : -4.252776145935059, sample : tensor([2.0195, 0.0153])
# => proposal weight : 2.0480082035064697, model weight : -1.6381115913391113, sample : tensor([ 2.0222, -0.1367])
# => proposal weight : 2.452749729156494, model weight : -7.314014434814453, sample : tensor([1.9724, 0.2266])
# => proposal weight : 2.97629451751709, model weight : -7.020406723022461, sample : tensor([1.9838, 0.1862])
# => proposal weight : 2.1369504928588867, model weight : -2.979762077331543, sample : tensor([1.9443, 0.2279])
# => proposal weight : 3.5886950492858887, model weight : -0.43445324897766113, sample : tensor([1.9849, 0.0528])
# => proposal weight : 3.0434622764587402, model weight : -1.5307945013046265, sample : tensor([1.9571, 0.0995])
# => proposal weight : 3.382460594177246, model weight : -12.898256301879883, sample : tensor([2.0356, 0.0451])
# => proposal weight : 3.3116376399993896, model weight : -0.41542911529541016, sample : tensor([ 2.0023, -0.0301])
# => proposal weight : 2.6525166034698486, model weight : -26.140039443969727, sample : tensor([2.0499, 0.0807])
# => proposal weight : 3.4123363494873047, model weight : -6.252873420715332, sample : tensor([ 2.0343, -0.0205])
# => proposal weight : 2.993730068206787, model weight : -7.381270408630371, sample : tensor([ 2.0468, -0.0642])
# => proposal weight : 2.875788927078247, model weight : -18.130870819091797, sample : tensor([ 2.0578, -0.0072])
# => proposal weight : 1.1276828050613403, model weight : -11.90589427947998, sample : tensor([1.9138, 0.1344])
# => proposal weight : 3.5498318672180176, model weight : -9.311114311218262, sample : tensor([2.0281, 0.0427])
# => proposal weight : 3.4930710792541504, model weight : -4.78381872177124, sample : tensor([1.9922, 0.1297])
# => proposal weight : 2.555769920349121, model weight : -1.1755642890930176, sample : tensor([ 2.0091, -0.0958])
# => proposal weight : 3.602262020111084, model weight : -0.4783964157104492, sample : tensor([1.9951, 0.0208])
# => proposal weight : 3.0963504314422607, model weight : -17.11827850341797, sample : tensor([2.0264, 0.1163])
# => proposal weight : 2.857728958129883, model weight : -2.8517727851867676, sample : tensor([1.9592, 0.0469])
# => proposal weight : 1.301387906074524, model weight : -10.191140174865723, sample : tensor([1.9161, 0.1435])
# => proposal weight : 3.625938892364502, model weight : -6.701677322387695, sample : tensor([2.0089, 0.0917])
# => proposal weight : 3.4026474952697754, model weight : -3.4668455123901367, sample : tensor([1.9830, 0.1416])
# => proposal weight : 2.927659273147583, model weight : -11.217469215393066, sample : tensor([ 2.0538, -0.0511])
# => proposal weight : 2.661949634552002, model weight : -14.927834510803223, sample : tensor([2.0020, 0.1929])
# => proposal weight : 1.5856858491897583, model weight : -7.609318256378174, sample : tensor([1.9206, 0.1566])
# => proposal weight : 2.6392476558685303, model weight : -23.643535614013672, sample : tensor([2.0627, 0.0109])
# => proposal weight : 3.557931900024414, model weight : -2.529700756072998, sample : tensor([1.9857, 0.1162])
# => proposal weight : 2.022125244140625, model weight : -23.31710433959961, sample : tensor([2.0113, 0.2151])
# => proposal weight : 3.1068882942199707, model weight : -1.4568030834197998, sample : tensor([ 2.0222, -0.0675])
# => proposal weight : 0.19159650802612305, model weight : -8.965974807739258, sample : tensor([ 2.0801, -0.2266])
# => proposal weight : 3.3053112030029297, model weight : -0.6283047199249268, sample : tensor([1.9813, 0.0153])
# => proposal weight : 3.128476142883301, model weight : -5.847400665283203, sample : tensor([ 2.0408, -0.0573])
# => proposal weight : 3.351872444152832, model weight : -12.27454662322998, sample : tensor([2.0397, 0.0221])
# => proposal weight : 2.34930682182312, model weight : -2.4754812717437744, sample : tensor([1.9454, 0.2087])
# => proposal weight : 3.274949073791504, model weight : -3.1899051666259766, sample : tensor([1.9773, 0.1553])
# => proposal weight : 3.282589912414551, model weight : -13.490334510803223, sample : tensor([2.0198, 0.1145])
# => proposal weight : 3.141167163848877, model weight : -17.848623275756836, sample : tensor([2.0388, 0.0714])
# => proposal weight : 3.109381675720215, model weight : -1.1470140218734741, sample : tensor([1.9593, 0.1308])
# => proposal weight : 2.7467041015625, model weight : -1.8811177015304565, sample : tensor([ 1.9876, -0.0494])
# => proposal weight : 2.2267494201660156, model weight : -19.500972747802734, sample : tensor([2.0052, 0.2137])
# => proposal weight : 3.1503472328186035, model weight : -6.314409255981445, sample : tensor([1.9861, 0.1703])
# => proposal weight : 1.0678861141204834, model weight : -44.04474639892578, sample : tensor([2.0463, 0.1877])
# => proposal weight : 1.9219709634780884, model weight : -16.449565887451172, sample : tensor([ 2.0768, -0.1097])
# => proposal weight : 3.016955852508545, model weight : -9.462129592895508, sample : tensor([1.9936, 0.1772])
# => proposal weight : 2.8861382007598877, model weight : -1.6713541746139526, sample : tensor([1.9516, 0.1341])
# => proposal weight : 2.6320409774780273, model weight : -25.73697280883789, sample : tensor([2.0421, 0.1102])
# => proposal weight : -0.34291017055511475, model weight : -29.50332260131836, sample : tensor([1.9865, 0.3392])
# => proposal weight : 0.5966780185699463, model weight : -8.952630043029785, sample : tensor([1.9046, 0.2275])
# => proposal weight : 2.5018911361694336, model weight : -5.286759376525879, sample : tensor([1.9657, 0.2222])
# => proposal weight : 3.6850266456604004, model weight : -1.8273025751113892, sample : tensor([2.0080, 0.0168])
# => proposal weight : 1.9727768898010254, model weight : -25.55454444885254, sample : tensor([2.0165, 0.2090])
# => proposal weight : 3.56024169921875, model weight : -0.40192270278930664, sample : tensor([1.9957, 0.0121])
# => proposal weight : 3.3662571907043457, model weight : -0.33798885345458984, sample : tensor([ 1.9935, -0.0088])
# => proposal weight : -0.3804655075073242, model weight : -22.668188095092773, sample : tensor([1.8917, 0.1442])
# => proposal weight : 3.484330177307129, model weight : -2.202237129211426, sample : tensor([1.9809, 0.1252])
# => proposal weight : 2.4597883224487305, model weight : -1.189003348350525, sample : tensor([ 2.0180, -0.1106])
# => proposal weight : 1.9140681028366089, model weight : -36.026241302490234, sample : tensor([2.0502, 0.1339])
# => proposal weight : 2.795910358428955, model weight : -13.725093841552734, sample : tensor([2.0018, 0.1845])
# => proposal weight : 3.6159138679504395, model weight : -0.5580945014953613, sample : tensor([1.9966, 0.0201])
# => proposal weight : 2.610322952270508, model weight : -17.975662231445312, sample : tensor([ 2.0654, -0.0428])
# => proposal weight : 3.2026526927948, model weight : -0.4646719694137573, sample : tensor([ 1.9985, -0.0344])
# => proposal weight : 3.410916328430176, model weight : -5.399780750274658, sample : tensor([1.9913, 0.1409])
# => proposal weight : 0.24119019508361816, model weight : -28.634950637817383, sample : tensor([1.9927, 0.3128])
# => proposal weight : 3.481473445892334, model weight : -0.3302788734436035, sample : tensor([1.9837, 0.0333])
# => proposal weight : -1.777033805847168, model weight : -54.85951614379883, sample : tensor([ 2.1391, -0.1646])
# => proposal weight : 3.4186763763427734, model weight : -3.0531492233276367, sample : tensor([ 2.0252, -0.0331])
# => proposal weight : 3.6349587440490723, model weight : -5.183608531951904, sample : tensor([2.0228, 0.0154])
# => proposal weight : 2.402928113937378, model weight : -3.3414549827575684, sample : tensor([1.9382, 0.1484])
# => proposal weight : 3.596914768218994, model weight : -1.2792612314224243, sample : tensor([1.9830, 0.0955])
# => proposal weight : 1.8126418590545654, model weight : -6.429096221923828, sample : tensor([1.9563, 0.2638])
# => proposal weight : 2.2475781440734863, model weight : -3.6954197883605957, sample : tensor([ 1.9857, -0.0761])
# => proposal weight : 2.764493465423584, model weight : -1.7483066320419312, sample : tensor([1.9516, 0.1718])
# => proposal weight : 3.528472900390625, model weight : -3.8673386573791504, sample : tensor([1.9899, 0.1245])
# => proposal weight : 3.7052102088928223, model weight : -1.3778692483901978, sample : tensor([1.9929, 0.0650])
# => proposal weight : 3.401170253753662, model weight : -4.3354172706604, sample : tensor([ 2.0302, -0.0315])
# => proposal weight : 2.5515902042388916, model weight : -2.7703609466552734, sample : tensor([ 1.9842, -0.0551])
# => proposal weight : 3.0224132537841797, model weight : -1.9607681035995483, sample : tensor([1.9619, 0.0566])
# => proposal weight : 2.920825242996216, model weight : -17.809572219848633, sample : tensor([2.0204, 0.1449])
# => proposal weight : 3.331728458404541, model weight : -11.508822441101074, sample : tensor([2.0413, 0.0079])
# => proposal weight : 3.481682777404785, model weight : -0.7946544885635376, sample : tensor([1.9751, 0.0990])
# => proposal weight : 3.5966153144836426, model weight : -0.40146875381469727, sample : tensor([1.9887, 0.0389])
# => proposal weight : 2.9899449348449707, model weight : -4.582858085632324, sample : tensor([1.9747, 0.1852])
# => proposal weight : 2.487685441970825, model weight : -1.1788356304168701, sample : tensor([ 2.0194, -0.1101])
# => proposal weight : 1.9901371002197266, model weight : -2.0520896911621094, sample : tensor([ 2.0125, -0.1305])
# => proposal weight : 3.728003978729248, model weight : -4.249669551849365, sample : tensor([2.0122, 0.0460])
# => proposal weight : 3.032944917678833, model weight : -11.488490104675293, sample : tensor([ 2.0515, -0.0377])
# => proposal weight : 3.656386375427246, model weight : -5.054224014282227, sample : tensor([2.0211, 0.0206])
# => proposal weight : 3.6419849395751953, model weight : -6.563041687011719, sample : tensor([2.0229, 0.0334])
# => proposal weight : 3.625593662261963, model weight : -0.49518704414367676, sample : tensor([1.9908, 0.0386])
# => proposal weight : 2.603273868560791, model weight : -20.327796936035156, sample : tensor([2.0179, 0.1716])
# => proposal weight : 2.9504852294921875, model weight : -2.349275588989258, sample : tensor([1.9620, 0.0455])
# => proposal weight : 3.5084714889526367, model weight : -0.4943962097167969, sample : tensor([1.9774, 0.0733])
# => proposal weight : 3.2009997367858887, model weight : -12.886908531188965, sample : tensor([2.0127, 0.1370])
# => proposal weight : 3.346808910369873, model weight : -10.72979736328125, sample : tensor([2.0407, 0.0029])
# => proposal weight : 2.498912811279297, model weight : -3.3293538093566895, sample : tensor([1.9564, 0.2150])
# => proposal weight : 1.9213521480560303, model weight : -12.248764991760254, sample : tensor([1.9780, 0.2556])
# => proposal weight : 2.5834341049194336, model weight : -4.466338157653809, sample : tensor([1.9519, 0.0504])
# => proposal weight : 2.1902663707733154, model weight : -24.365158081054688, sample : tensor([ 2.0761, -0.0441])
# => proposal weight : 2.8159584999084473, model weight : -2.601433753967285, sample : tensor([1.9509, 0.0954])
# => proposal weight : 3.207115411758423, model weight : -1.2204898595809937, sample : tensor([1.9647, 0.1382])
# => proposal weight : 3.3818840980529785, model weight : -0.33030128479003906, sample : tensor([ 1.9964, -0.0129])
# => proposal weight : 2.4048404693603516, model weight : -3.7384390830993652, sample : tensor([1.9383, 0.1356])
# => proposal weight : 3.1861371994018555, model weight : -1.0056616067886353, sample : tensor([1.9617, 0.1166])
# => proposal weight : 3.1633148193359375, model weight : -1.3915010690689087, sample : tensor([ 2.0208, -0.0618])
# => proposal weight : 3.289583921432495, model weight : -0.4726982116699219, sample : tensor([ 2.0048, -0.0359])
# => proposal weight : 2.0575618743896484, model weight : -22.467330932617188, sample : tensor([ 2.0786, -0.0688])
# => proposal weight : 3.6887521743774414, model weight : -4.535924434661865, sample : tensor([2.0029, 0.0867])
# => proposal weight : 2.6222410202026367, model weight : -8.869922637939453, sample : tensor([1.9815, 0.2131])
# => proposal weight : 3.2824811935424805, model weight : -3.4354796409606934, sample : tensor([1.9786, 0.1553])
# => proposal weight : 3.2992911338806152, model weight : -0.4784996509552002, sample : tensor([ 1.9887, -0.0053])
# => proposal weight : -1.4556975364685059, model weight : -36.46624755859375, sample : tensor([ 1.9138, -0.0402])
# => proposal weight : 3.04683256149292, model weight : -3.9281728267669678, sample : tensor([1.9735, 0.1790])
# => proposal weight : 2.8781490325927734, model weight : -2.212985038757324, sample : tensor([ 1.9755, -0.0104])
# => proposal weight : 3.2377963066101074, model weight : -16.07784080505371, sample : tensor([2.0354, 0.0721])
# => proposal weight : 2.905881643295288, model weight : -9.559873580932617, sample : tensor([ 2.0522, -0.0623])
# => proposal weight : 2.012678861618042, model weight : -7.3717875480651855, sample : tensor([ 1.9614, -0.0305])
# => proposal weight : 2.7403886318206787, model weight : -24.708120346069336, sample : tensor([2.0482, 0.0787])
# => proposal weight : 3.15604305267334, model weight : -0.8035756349563599, sample : tensor([ 1.9871, -0.0159])
# => proposal weight : 2.517946481704712, model weight : -26.684572219848633, sample : tensor([2.0393, 0.1272])
# => proposal weight : 2.8534631729125977, model weight : -2.215280055999756, sample : tensor([ 2.0313, -0.0908])
# => proposal weight : 2.4642229080200195, model weight : -18.94647979736328, sample : tensor([ 2.0691, -0.0518])
# => proposal weight : 3.348702907562256, model weight : -0.9161754846572876, sample : tensor([ 2.0125, -0.0383])
# => proposal weight : 3.309230327606201, model weight : -0.779244065284729, sample : tensor([1.9714, 0.0559])
# => proposal weight : 3.3935418128967285, model weight : -2.4937996864318848, sample : tensor([ 2.0234, -0.0372])
# => proposal weight : 3.2890138626098633, model weight : -7.178583145141602, sample : tensor([ 2.0395, -0.0324])
# => proposal weight : 3.3213887214660645, model weight : -0.5705890655517578, sample : tensor([1.9824, 0.0141])
# => proposal weight : 2.762554407119751, model weight : -1.703607439994812, sample : tensor([ 2.0284, -0.0972])
# => proposal weight : 3.702528953552246, model weight : -3.7332448959350586, sample : tensor([2.0151, 0.0257])
# => proposal weight : 3.4319310188293457, model weight : -1.8022502660751343, sample : tensor([ 2.0184, -0.0320])
# => proposal weight : 3.237332820892334, model weight : -1.0254181623458862, sample : tensor([1.9685, 0.0576])
# => proposal weight : 0.5327613353729248, model weight : -57.271541595458984, sample : tensor([2.0911, 0.0615])
# => proposal weight : 2.610866069793701, model weight : -25.225078582763672, sample : tensor([2.0375, 0.1255])
# => proposal weight : 2.9915595054626465, model weight : -4.792783260345459, sample : tensor([1.9756, 0.1853])
# => proposal weight : 1.8153196573257446, model weight : -36.236228942871094, sample : tensor([2.0461, 0.1514])
# => proposal weight : 3.42531156539917, model weight : -0.6012685298919678, sample : tensor([1.9723, 0.0869])
# => proposal weight : 2.3953282833099365, model weight : -5.585452079772949, sample : tensor([1.9459, 0.0602])
# => proposal weight : 3.681654930114746, model weight : -3.9404492378234863, sample : tensor([1.9993, 0.0916])
# => proposal weight : 1.3762990236282349, model weight : -3.506345748901367, sample : tensor([ 2.0503, -0.1814])
# => proposal weight : 2.8617401123046875, model weight : -1.7663627862930298, sample : tensor([ 2.0279, -0.0896])
# => proposal weight : 2.6810660362243652, model weight : -14.587121963500977, sample : tensor([ 2.0621, -0.0568])
# => proposal weight : 3.00020694732666, model weight : -2.0065689086914062, sample : tensor([1.9592, 0.0687])
# => proposal weight : 2.9337942600250244, model weight : -1.6991719007492065, sample : tensor([1.9529, 0.1197])
# => proposal weight : 3.6271862983703613, model weight : -7.7541279792785645, sample : tensor([2.0173, 0.0702])
# => proposal weight : 3.5760726928710938, model weight : -8.141852378845215, sample : tensor([2.0277, 0.0315])
# => proposal weight : 3.598271369934082, model weight : -1.368376612663269, sample : tensor([1.9834, 0.0970])
# => proposal weight : 3.5735669136047363, model weight : -8.022126197814941, sample : tensor([2.0117, 0.0953])
# => proposal weight : 3.253378391265869, model weight : -0.8185566663742065, sample : tensor([1.9788, 0.0169])
# => proposal weight : 3.5723977088928223, model weight : -1.2593752145767212, sample : tensor([1.9815, 0.0997])
# => proposal weight : 1.8729661703109741, model weight : -22.548904418945312, sample : tensor([2.0059, 0.2305])
# => proposal weight : 2.7386527061462402, model weight : -6.19937801361084, sample : tensor([ 2.0486, -0.0913])
# => proposal weight : 3.486825942993164, model weight : -0.7849466800689697, sample : tensor([ 2.0073, -0.0172])
# => proposal weight : 3.6453733444213867, model weight : -2.3074097633361816, sample : tensor([1.9897, 0.0980])
# => proposal weight : 2.162810802459717, model weight : -24.854629516601562, sample : tensor([ 2.0768, -0.0436])
# => proposal weight : 3.2839627265930176, model weight : -0.4070788621902466, sample : tensor([ 2.0011, -0.0312])
# => proposal weight : 3.3131322860717773, model weight : -0.7696174383163452, sample : tensor([1.9705, 0.0617])
# => proposal weight : 3.5703654289245605, model weight : -2.7800984382629395, sample : tensor([1.9874, 0.1152])
# => proposal weight : 2.0538363456726074, model weight : -1.7807667255401611, sample : tensor([ 2.0307, -0.1420])
# => proposal weight : 3.653599262237549, model weight : -6.18354606628418, sample : tensor([2.0219, 0.0327])
# => proposal weight : 3.3985180854797363, model weight : -6.849531173706055, sample : tensor([ 2.0357, -0.0190])
# => proposal weight : 3.72444486618042, model weight : -4.013696193695068, sample : tensor([2.0046, 0.0727])
# => proposal weight : 3.715303421020508, model weight : -4.207732200622559, sample : tensor([2.0043, 0.0768])
# => proposal weight : 3.637322425842285, model weight : -7.55096960067749, sample : tensor([2.0196, 0.0586])
# => proposal weight : 3.6347527503967285, model weight : -6.229754447937012, sample : tensor([2.0070, 0.0933])
# => proposal weight : 3.578385829925537, model weight : -2.382786273956299, sample : tensor([ 2.0170, -0.0093])
# => proposal weight : 2.228274345397949, model weight : -3.284928798675537, sample : tensor([ 1.9903, -0.0860])
# => proposal weight : 2.9648337364196777, model weight : -10.799785614013672, sample : tensor([1.9967, 0.1783])
# => proposal weight : 0.20699381828308105, model weight : -22.715167999267578, sample : tensor([1.9174, 0.0255])
# => proposal weight : 3.539799213409424, model weight : -0.8171168565750122, sample : tensor([1.9784, 0.0922])
# => proposal weight : 3.3246748447418213, model weight : -1.4473928213119507, sample : tensor([1.9707, 0.1349])
# => proposal weight : 2.926269292831421, model weight : -1.4625409841537476, sample : tensor([1.9546, 0.1530])
# => proposal weight : 0.7067598104476929, model weight : -5.049008369445801, sample : tensor([ 2.0624, -0.2117])
# => proposal weight : 2.734419584274292, model weight : -2.973665714263916, sample : tensor([ 1.9725, -0.0135])
# => proposal weight : 2.3989548683166504, model weight : -15.781864166259766, sample : tensor([ 2.0685, -0.0761])
# => proposal weight : 3.255558490753174, model weight : -0.9190582036972046, sample : tensor([1.9646, 0.1173])
# => proposal weight : 2.684454917907715, model weight : -2.5189270973205566, sample : tensor([1.9455, 0.1306])
# => proposal weight : 3.571845531463623, model weight : -3.843092441558838, sample : tensor([ 2.0229, -0.0068])
# => proposal weight : 3.728297710418701, model weight : -3.2988152503967285, sample : tensor([2.0013, 0.0739])
# => proposal weight : 3.300290584564209, model weight : -11.002219200134277, sample : tensor([ 2.0427, -0.0032])
# => proposal weight : 2.877655267715454, model weight : -2.6224875450134277, sample : tensor([1.9670, 0.0169])
# => proposal weight : 3.1276469230651855, model weight : -1.4345875978469849, sample : tensor([1.9707, 0.0306])
# => proposal weight : 2.4934706687927246, model weight : -4.052341938018799, sample : tensor([1.9600, 0.2193])
# => proposal weight : -0.027480721473693848, model weight : -38.502891540527344, sample : tensor([ 2.1150, -0.1363])
# => proposal weight : 3.4238343238830566, model weight : -0.3325631618499756, sample : tensor([1.9875, 0.0125])
# => proposal weight : 2.195895195007324, model weight : -6.795255661010742, sample : tensor([1.9404, 0.0683])
# => proposal weight : 2.6573925018310547, model weight : -17.78782844543457, sample : tensor([ 2.0642, -0.0388])
# => proposal weight : 3.5994977951049805, model weight : -5.576273441314697, sample : tensor([2.0254, 0.0095])
# => proposal weight : 3.2333152294158936, model weight : -3.3843259811401367, sample : tensor([1.9768, 0.1602])
# => proposal weight : 2.2637696266174316, model weight : -27.431163787841797, sample : tensor([ 2.0732, -0.0107])
# => proposal weight : 2.276588201522827, model weight : -4.240164756774902, sample : tensor([ 1.9795, -0.0614])
# => proposal weight : 2.630871534347534, model weight : -24.01702308654785, sample : tensor([2.0329, 0.1366])
# => proposal weight : 3.5455403327941895, model weight : -5.527976989746094, sample : tensor([ 2.0280, -0.0025])
# => proposal weight : 1.866847276687622, model weight : -20.151525497436523, sample : tensor([1.9992, 0.2395])
# => proposal weight : 2.9212918281555176, model weight : -17.965639114379883, sample : tensor([ 2.0561e+00, -1.3857e-03])
# => proposal weight : 3.2967159748077393, model weight : -1.5999139547348022, sample : tensor([1.9704, 0.1402])
# => proposal weight : 3.46488356590271, model weight : -4.8955464363098145, sample : tensor([ 2.0297, -0.0199])
# => proposal weight : 2.4962940216064453, model weight : -2.458916187286377, sample : tensor([1.9417, 0.1657])
# => proposal weight : 3.688511848449707, model weight : -1.370486855506897, sample : tensor([2.0037, 0.0227])
# => proposal weight : 3.3915181159973145, model weight : -8.266058921813965, sample : tensor([2.0021, 0.1343])
# => proposal weight : 1.7914105653762817, model weight : -5.7546281814575195, sample : tensor([ 2.0584, -0.1558])
# => proposal weight : 3.258307933807373, model weight : -15.682642936706543, sample : tensor([2.0364, 0.0650])
# => proposal weight : 3.691866874694824, model weight : -5.644991397857666, sample : tensor([2.0173, 0.0449])
# => proposal weight : 3.410073757171631, model weight : -7.192107677459717, sample : tensor([1.9985, 0.1361])
# => proposal weight : 3.3258514404296875, model weight : -0.9973539113998413, sample : tensor([1.9683, 0.1218])
# => proposal weight : 1.053880214691162, model weight : -12.994293212890625, sample : tensor([1.9136, 0.1239])
# => proposal weight : 0.1583104133605957, model weight : -5.180747985839844, sample : tensor([ 2.0237, -0.2171])
# => proposal weight : 3.598712921142578, model weight : -2.4501142501831055, sample : tensor([ 2.0164, -0.0054])
# => proposal weight : 2.477037191390991, model weight : -13.366578102111816, sample : tensor([ 2.0649, -0.0818])
# => proposal weight : 3.250309467315674, model weight : -0.8369787931442261, sample : tensor([ 2.0132, -0.0488])
# => proposal weight : 3.406261920928955, model weight : -0.3149406909942627, sample : tensor([ 1.9920e+00, -9.1064e-04])
# => proposal weight : 2.9875495433807373, model weight : -20.395145416259766, sample : tensor([2.0391, 0.0881])
# => proposal weight : 3.7420406341552734, model weight : -3.604719638824463, sample : tensor([2.0079, 0.0529])
# => proposal weight : 3.1649680137634277, model weight : -0.6806275844573975, sample : tensor([ 2.0113, -0.0548])
# => proposal weight : 3.026608467102051, model weight : -3.0246658325195312, sample : tensor([1.9688, 0.1773])
# => proposal weight : 2.9017717838287354, model weight : -2.1859726905822754, sample : tensor([1.9532, 0.0955])
# => proposal weight : 0.6499971151351929, model weight : -3.3126025199890137, sample : tensor([ 2.0353, -0.2081])
# => proposal weight : 3.5476675033569336, model weight : -0.42103052139282227, sample : tensor([1.9973, 0.0068])
# => proposal weight : 0.6013542413711548, model weight : -32.882476806640625, sample : tensor([ 2.1051, -0.1229])
# => proposal weight : 2.454374313354492, model weight : -19.17824363708496, sample : tensor([ 2.0694, -0.0513])
# => proposal weight : 3.372002601623535, model weight : -1.6040371656417847, sample : tensor([ 2.0185, -0.0394])
# => proposal weight : 3.3899354934692383, model weight : -0.8841623067855835, sample : tensor([ 2.0112, -0.0327])
# => proposal weight : 2.4060871601104736, model weight : -5.195137977600098, sample : tensor([ 1.9627, -0.0082])
# => proposal weight : 3.1528890132904053, model weight : -13.553735733032227, sample : tensor([2.0133, 0.1402])
# => proposal weight : 3.012763023376465, model weight : -1.3292540311813354, sample : tensor([1.9558, 0.1326])
# => proposal weight : 3.7145204544067383, model weight : -2.746753215789795, sample : tensor([2.0107, 0.0260])
# => proposal weight : 1.8946800231933594, model weight : -7.637495517730713, sample : tensor([ 1.9646, -0.0465])
# => proposal weight : 0.901583194732666, model weight : -50.16822814941406, sample : tensor([2.0927, 0.0238])
# => proposal weight : 2.756460189819336, model weight : -6.687934875488281, sample : tensor([ 2.0495, -0.0881])
# => proposal weight : 3.1461129188537598, model weight : -10.443100929260254, sample : tensor([ 2.0475, -0.0306])
# => proposal weight : 3.281431198120117, model weight : -0.8511844873428345, sample : tensor([1.9673, 0.0762])
# => proposal weight : 3.268427848815918, model weight : -1.1961103677749634, sample : tensor([ 2.0172, -0.0499])
# => proposal weight : 0.9479180574417114, model weight : -13.801454544067383, sample : tensor([1.9663, 0.3063])
# => proposal weight : -0.02262425422668457, model weight : -65.33782958984375, sample : tensor([2.0956, 0.0750])
# => proposal weight : 3.4102530479431152, model weight : -7.3180718421936035, sample : tensor([1.9991, 0.1356])
# => proposal weight : 3.6620736122131348, model weight : -0.8438855409622192, sample : tensor([1.9987, 0.0253])
# => proposal weight : 3.5525689125061035, model weight : -2.6037564277648926, sample : tensor([ 2.0190, -0.0137])
# => proposal weight : 0.47738325595855713, model weight : -3.517915725708008, sample : tensor([ 2.0370, -0.2158])
# => proposal weight : 1.8719245195388794, model weight : -7.936145305633545, sample : tensor([ 1.9631, -0.0435])
# => proposal weight : 1.4039027690887451, model weight : -5.302380561828613, sample : tensor([ 1.9961, -0.1353])
# => proposal weight : 1.8887497186660767, model weight : -9.469963073730469, sample : tensor([ 2.0671, -0.1391])
# => proposal weight : 0.6243377923965454, model weight : -12.697108268737793, sample : tensor([1.9582, 0.3221])
# => proposal weight : 3.3497142791748047, model weight : -12.94400405883789, sample : tensor([2.0388, 0.0321])
# => proposal weight : 3.233250856399536, model weight : -1.0273748636245728, sample : tensor([1.9715, 0.0419])
# => proposal weight : 3.5416131019592285, model weight : -0.3087577819824219, sample : tensor([1.9891, 0.0262])
# => proposal weight : 3.1626155376434326, model weight : -0.5163969993591309, sample : tensor([ 1.9980, -0.0371])
# => proposal weight : 3.6172432899475098, model weight : -6.6256208419799805, sample : tensor([2.0076, 0.0955])
# => proposal weight : 1.90962553024292, model weight : -3.1877546310424805, sample : tensor([1.9394, 0.2381])
# => proposal weight : 3.737311363220215, model weight : -1.900560975074768, sample : tensor([2.0004, 0.0497])
# => proposal weight : 0.9941391944885254, model weight : -7.533079624176025, sample : tensor([ 1.9911, -0.1441])
# => proposal weight : 3.226227283477783, model weight : -16.18877601623535, sample : tensor([2.0332, 0.0819])
# => proposal weight : 1.7967127561569214, model weight : -29.0826473236084, sample : tensor([2.0222, 0.2072])
# => proposal weight : 0.8361352682113647, model weight : -20.18072509765625, sample : tensor([1.9815, 0.3017])
# => proposal weight : 3.510796546936035, model weight : -10.558012008666992, sample : tensor([2.0237, 0.0730])
# => proposal weight : 1.4138424396514893, model weight : -12.58975601196289, sample : tensor([ 2.0779, -0.1563])
# => proposal weight : 3.3195929527282715, model weight : -0.37597084045410156, sample : tensor([ 1.9994, -0.0249])
# => proposal weight : 3.544800281524658, model weight : -7.165991306304932, sample : tensor([2.0300, 0.0105])
# => proposal weight : 1.2521642446517944, model weight : -3.9088988304138184, sample : tensor([ 2.0535, -0.1874])
# => proposal weight : 3.211775302886963, model weight : -16.114030838012695, sample : tensor([2.0419, 0.0455])
# => proposal weight : 2.8326034545898438, model weight : -6.420382499694824, sample : tensor([1.9778, 0.1990])
# => proposal weight : 3.303032398223877, model weight : -14.078019142150879, sample : tensor([2.0248, 0.0994])
# => proposal weight : 3.665142059326172, model weight : -1.1552163362503052, sample : tensor([1.9881, 0.0754])
# => proposal weight : 3.61006498336792, model weight : -6.653432369232178, sample : tensor([2.0256, 0.0228])
# => proposal weight : 2.9717445373535156, model weight : -1.7421928644180298, sample : tensor([1.9597, 0.1670])
# => proposal weight : 1.717647910118103, model weight : -37.58100128173828, sample : tensor([2.0815, 0.0112])
# => proposal weight : 3.7102293968200684, model weight : -1.2839492559432983, sample : tensor([1.9992, 0.0382])
# => proposal weight : 1.1915168762207031, model weight : -48.32901382446289, sample : tensor([2.0762, 0.0855])
# => proposal weight : 3.4988698959350586, model weight : -8.956657409667969, sample : tensor([2.0330, 0.0182])
# => proposal weight : 2.349719285964966, model weight : -5.452503681182861, sample : tensor([1.9410, 0.0859])
# => proposal weight : 1.9535595178604126, model weight : -1.91494619846344, sample : tensor([ 2.0326, -0.1482])
# => proposal weight : 3.5765938758850098, model weight : -0.36860013008117676, sample : tensor([1.9866, 0.0421])
# => proposal weight : 3.7136192321777344, model weight : -2.729135036468506, sample : tensor([2.0107, 0.0256])
# => proposal weight : 2.0176243782043457, model weight : -35.8027229309082, sample : tensor([2.0679, 0.0598])
# => proposal weight : 3.035761594772339, model weight : -2.5478310585021973, sample : tensor([ 2.0308, -0.0752])
# => proposal weight : 1.69638991355896, model weight : -7.337454319000244, sample : tensor([1.9229, 0.1483])
# => proposal weight : 2.2652151584625244, model weight : -21.763519287109375, sample : tensor([2.0127, 0.2002])
# => proposal weight : 2.5276248455047607, model weight : -6.6340837478637695, sample : tensor([1.9715, 0.2216])
# => proposal weight : 0.24046039581298828, model weight : -5.289492130279541, sample : tensor([ 2.0652, -0.2317])
# => proposal weight : 3.1052703857421875, model weight : -9.853547096252441, sample : tensor([ 2.0480, -0.0393])
# => proposal weight : 2.4574179649353027, model weight : -3.3937697410583496, sample : tensor([ 1.9810, -0.0540])
# => proposal weight : 0.07286572456359863, model weight : -51.78815460205078, sample : tensor([ 2.1137, -0.0612])
# => proposal weight : 2.173720359802246, model weight : -4.96980619430542, sample : tensor([1.9572, 0.2412])
# => proposal weight : 3.1487767696380615, model weight : -17.668869018554688, sample : tensor([2.0404, 0.0635])
# => proposal weight : 3.5725226402282715, model weight : -7.1678900718688965, sample : tensor([2.0070, 0.1042])
# => proposal weight : 1.8322091102600098, model weight : -26.540494918823242, sample : tensor([ 2.0839, -0.0647])
# => proposal weight : 3.7417030334472656, model weight : -2.92578125, sample : tensor([2.0075, 0.0428])
# => proposal weight : 3.3303380012512207, model weight : -8.728898048400879, sample : tensor([2.0014, 0.1416])
# => proposal weight : 3.440317153930664, model weight : -2.03311824798584, sample : tensor([ 2.0196, -0.0311])
# => proposal weight : 3.5949907302856445, model weight : -8.241499900817871, sample : tensor([2.0254, 0.0425])
# => proposal weight : 3.712584972381592, model weight : -1.2601898908615112, sample : tensor([1.9959, 0.0505])
# => proposal weight : 0.733893871307373, model weight : -42.4842643737793, sample : tensor([ 2.1039, -0.0628])
# => proposal weight : 3.29365873336792, model weight : -10.269302368164062, sample : tensor([2.0061, 0.1392])
# => proposal weight : 3.1779818534851074, model weight : -1.1344224214553833, sample : tensor([1.9755, 0.0190])
# => proposal weight : 3.5986132621765137, model weight : -1.2462726831436157, sample : tensor([1.9831, 0.0945])
# => proposal weight : -0.1059727668762207, model weight : -26.61786460876465, sample : tensor([ 2.1092, -0.1864])
# ...
# => proposal weight : 1.2748357057571411, model weight : -34.13066482543945, sample : tensor([ 2.0949, -0.0676])
# => proposal weight : 3.154479742050171, model weight : -15.923008918762207, sample : tensor([2.0470, 0.0222])
# => proposal weight : 3.0450756549835205, model weight : -17.677282333374023, sample : tensor([2.0507, 0.0200])
# => proposal weight : 3.398775577545166, model weight : -12.490925788879395, sample : tensor([2.0236, 0.0908])
# => proposal weight : 3.5361318588256836, model weight : -0.9283708333969116, sample : tensor([ 2.0075, -0.0107])
# => proposal weight : 1.2818771600723267, model weight : -36.99359130859375, sample : tensor([2.0316, 0.2120])
# => proposal weight : 2.4941234588623047, model weight : -20.770017623901367, sample : tensor([2.0160, 0.1817])
# => proposal weight : 3.328784942626953, model weight : -0.37589430809020996, sample : tensor([ 1.9930, -0.0118])
# => proposal weight : 2.555117130279541, model weight : -7.54128360748291, sample : tensor([1.9754, 0.2194])
# => proposal weight : 3.559757709503174, model weight : -6.413054943084717, sample : tensor([2.0285, 0.0071])
# => proposal weight : 2.53855562210083, model weight : -16.602718353271484, sample : tensor([2.0041, 0.1977])
# => proposal weight : 1.6110864877700806, model weight : -6.800901889801025, sample : tensor([1.9540, 0.2746])
# => proposal weight : 1.1382874250411987, model weight : -14.462441444396973, sample : tensor([ 1.9428, -0.0215])
# => proposal weight : 3.36312198638916, model weight : -1.4085887670516968, sample : tensor([1.9721, 0.1303])
# => proposal weight : 3.7156448364257812, model weight : -4.956438064575195, sample : tensor([2.0136, 0.0504])
# => proposal weight : 2.8269476890563965, model weight : -1.0206607580184937, sample : tensor([ 1.9997, -0.0656])
# => proposal weight : 3.1844987869262695, model weight : -16.77939224243164, sample : tensor([2.0324, 0.0899])
# => proposal weight : 3.1391913890838623, model weight : -1.2456165552139282, sample : tensor([1.9761, 0.0127])
# => proposal weight : 2.8217921257019043, model weight : -14.672248840332031, sample : tensor([ 2.0589, -0.0414])
# => proposal weight : 3.4522976875305176, model weight : -9.761223793029785, sample : tensor([2.0355, 0.0158])
# => proposal weight : 3.2542548179626465, model weight : -10.837959289550781, sample : tensor([2.0067, 0.1420])
# => proposal weight : 3.592097759246826, model weight : -1.821954369544983, sample : tensor([ 2.0131, -0.0061])
# => proposal weight : 3.498721122741699, model weight : -10.123661041259766, sample : tensor([2.0317, 0.0357])
# => proposal weight : 3.139523983001709, model weight : -10.428732872009277, sample : tensor([2.0009, 0.1599])
# => proposal weight : 3.533848762512207, model weight : -0.40698909759521484, sample : tensor([1.9975, 0.0042])
# => proposal weight : 2.5157127380371094, model weight : -13.45464038848877, sample : tensor([ 2.0643, -0.0781])
# => proposal weight : 3.5632143020629883, model weight : -6.735614776611328, sample : tensor([2.0287, 0.0108])
# => proposal weight : 1.7995408773422241, model weight : -3.9365241527557373, sample : tensor([1.9434, 0.2540])
# => proposal weight : 3.364217758178711, model weight : -0.5424379110336304, sample : tensor([1.9793, 0.0301])
# => proposal weight : 2.507784366607666, model weight : -18.556615829467773, sample : tensor([2.0093, 0.1919])
# => proposal weight : 3.4399795532226562, model weight : -1.2194446325302124, sample : tensor([ 2.0136, -0.0287])
# => proposal weight : 2.6364340782165527, model weight : -2.099882125854492, sample : tensor([1.9513, 0.1905])
# => proposal weight : 3.0485188961029053, model weight : -1.4738401174545288, sample : tensor([1.9571, 0.1032])
# => proposal weight : 0.6650915145874023, model weight : -5.967403411865234, sample : tensor([1.9112, 0.2642])
# => proposal weight : 3.729586601257324, model weight : -3.5735888481140137, sample : tensor([2.0115, 0.0378])
# => proposal weight : 3.710452079772949, model weight : -3.7905044555664062, sample : tensor([2.0144, 0.0294])
# => proposal weight : 3.6804795265197754, model weight : -3.3307080268859863, sample : tensor([1.9965, 0.0925])
# => proposal weight : 2.805131196975708, model weight : -21.964519500732422, sample : tensor([2.0329, 0.1237])
# => proposal weight : 2.9856438636779785, model weight : -3.3655996322631836, sample : tensor([ 2.0355, -0.0786])
# => proposal weight : 2.0840930938720703, model weight : -3.0326156616210938, sample : tensor([1.9345, 0.2011])
# => proposal weight : 3.602170467376709, model weight : -3.4926486015319824, sample : tensor([ 2.0205, -0.0023])
# => proposal weight : 3.3394362926483154, model weight : -10.570201873779297, sample : tensor([2.0094, 0.1294])
# => proposal weight : 3.632805347442627, model weight : -1.8866239786148071, sample : tensor([1.9873, 0.0971])
# => proposal weight : 3.6562557220458984, model weight : -4.382205486297607, sample : tensor([1.9994, 0.0978])
# => proposal weight : 2.726928234100342, model weight : -12.602872848510742, sample : tensor([1.9963, 0.1954])
# => proposal weight : 1.5092159509658813, model weight : -5.925547122955322, sample : tensor([ 2.0613, -0.1709])
# => proposal weight : 3.601703643798828, model weight : -0.6059465408325195, sample : tensor([1.9834, 0.0684])
# => proposal weight : 3.537752628326416, model weight : -9.909975051879883, sample : tensor([2.0269, 0.0538])
# => proposal weight : 3.598112106323242, model weight : -2.1162500381469727, sample : tensor([ 2.0147, -0.0055])
# => proposal weight : 2.272059440612793, model weight : -2.8663222789764404, sample : tensor([ 2.0412, -0.1318])
# => proposal weight : 2.3844311237335205, model weight : -16.839794158935547, sample : tensor([ 2.0696, -0.0717])
# => proposal weight : 2.9102611541748047, model weight : -1.8853949308395386, sample : tensor([1.9524, 0.1131])
# => proposal weight : 2.6604535579681396, model weight : -25.130144119262695, sample : tensor([2.0583, 0.0392])
# => proposal weight : 1.6145479679107666, model weight : -10.57834529876709, sample : tensor([1.9277, 0.0817])
# => proposal weight : 2.0536928176879883, model weight : -25.08898162841797, sample : tensor([2.0172, 0.2037])
# => proposal weight : 1.388243317604065, model weight : -9.293258666992188, sample : tensor([ 2.0718, -0.1684])
# => proposal weight : 3.5957865715026855, model weight : -0.9230672121047974, sample : tensor([1.9822, 0.0861])
# => proposal weight : 3.158809185028076, model weight : -0.49543488025665283, sample : tensor([ 2.0029, -0.0452])
# => proposal weight : 0.39691805839538574, model weight : -17.126501083374023, sample : tensor([ 1.9552, -0.0924])
# => proposal weight : 3.2357444763183594, model weight : -15.552552223205566, sample : tensor([2.0284, 0.0967])
# => proposal weight : 3.3660483360290527, model weight : -0.9383977651596069, sample : tensor([1.9698, 0.1163])
# => proposal weight : -0.33249378204345703, model weight : -50.466026306152344, sample : tensor([ 2.1207, -0.0995])
# => proposal weight : 2.5804028511047363, model weight : -11.55202579498291, sample : tensor([1.9893, 0.2110])
# => proposal weight : 2.392129421234131, model weight : -14.130599975585938, sample : tensor([1.9931, 0.2190])
# => proposal weight : 2.9422919750213623, model weight : -1.7611149549484253, sample : tensor([1.9533, 0.1129])
# => proposal weight : 2.285224199295044, model weight : -3.8176426887512207, sample : tensor([ 1.9832, -0.0690])
# => proposal weight : 2.171123504638672, model weight : -3.6241140365600586, sample : tensor([1.9501, 0.2347])
# => proposal weight : 3.7035651206970215, model weight : -1.4593266248703003, sample : tensor([1.9925, 0.0685])
# => proposal weight : 3.46677827835083, model weight : -10.293166160583496, sample : tensor([2.0342, 0.0270])
# => proposal weight : 3.6952548027038574, model weight : -3.7329673767089844, sample : tensor([1.9996, 0.0875])
# => proposal weight : 2.835184097290039, model weight : -0.8241610527038574, sample : tensor([ 2.0132, -0.0821])
# => proposal weight : 3.2224416732788086, model weight : -1.6896389722824097, sample : tensor([1.9682, 0.1484])
# => proposal weight : 2.5817480087280273, model weight : -12.511117935180664, sample : tensor([1.9924, 0.2083])
# => proposal weight : 2.7980828285217285, model weight : -10.068599700927734, sample : tensor([1.9898, 0.1964])
# => proposal weight : 3.2069764137268066, model weight : -16.14202880859375, sample : tensor([2.0423, 0.0439])
# => proposal weight : 3.612720012664795, model weight : -6.9665751457214355, sample : tensor([2.0254, 0.0277])
# => proposal weight : 3.5564985275268555, model weight : -5.297889709472656, sample : tensor([1.9974, 0.1177])
# => proposal weight : 3.418142795562744, model weight : -11.89146900177002, sample : tensor([2.0352, 0.0378])
# => proposal weight : 2.777674674987793, model weight : -19.006528854370117, sample : tensor([2.0192, 0.1575])
# => proposal weight : 3.352306842803955, model weight : -13.214302062988281, sample : tensor([2.0379, 0.0385])
# => proposal weight : 3.40140962600708, model weight : -12.46087646484375, sample : tensor([2.0237, 0.0902])
# => proposal weight : 3.328151226043701, model weight : -13.990723609924316, sample : tensor([2.0376, 0.0464])
# => proposal weight : 1.510016679763794, model weight : -10.226011276245117, sample : tensor([1.9220, 0.1131])
# => proposal weight : 2.975189447402954, model weight : -18.303157806396484, sample : tensor([2.0250, 0.1302])
# => proposal weight : 2.834980010986328, model weight : -4.804483890533447, sample : tensor([1.9716, 0.1979])
# => proposal weight : 2.598994255065918, model weight : -4.30800724029541, sample : tensor([1.9506, 0.0591])
# => proposal weight : 3.527371883392334, model weight : -1.6165217161178589, sample : tensor([ 2.0142, -0.0172])
# => proposal weight : 3.442357063293457, model weight : -1.7374907732009888, sample : tensor([1.9770, 0.1263])
# => proposal weight : 2.8989200592041016, model weight : -2.887671947479248, sample : tensor([1.9645, 0.1862])
# => proposal weight : 1.7807857990264893, model weight : -9.855255126953125, sample : tensor([1.9680, 0.2666])
# => proposal weight : 3.1962928771972656, model weight : -1.0160948038101196, sample : tensor([1.9625, 0.1244])
# => proposal weight : 2.8228015899658203, model weight : -23.18691062927246, sample : tensor([2.0506, 0.0594])
# => proposal weight : 1.578564167022705, model weight : -42.4683723449707, sample : tensor([2.0743, 0.0662])
# => proposal weight : 3.5009398460388184, model weight : -3.1606502532958984, sample : tensor([1.9857, 0.1276])
# => proposal weight : 2.6165049076080322, model weight : -26.72796058654785, sample : tensor([2.0509, 0.0800])
# => proposal weight : 3.640101909637451, model weight : -0.5858108997344971, sample : tensor([1.9940, 0.0319])
# => proposal weight : 2.9875640869140625, model weight : -15.546958923339844, sample : tensor([ 2.0545, -0.0135])
# => proposal weight : 3.516423225402832, model weight : -0.30125904083251953, sample : tensor([1.9868, 0.0290])
# => proposal weight : 2.8240344524383545, model weight : -3.1597471237182617, sample : tensor([ 2.0369, -0.0925])
# => proposal weight : 3.390305995941162, model weight : -9.189685821533203, sample : tensor([2.0059, 0.1294])
# => proposal weight : 3.0437045097351074, model weight : -19.28736114501953, sample : tensor([2.0460, 0.0521])
# => proposal weight : 1.1918238401412964, model weight : -26.051794052124023, sample : tensor([ 2.0941, -0.1159])
# => proposal weight : 2.3310043811798096, model weight : -19.982852935791016, sample : tensor([2.0091, 0.2024])
# => proposal weight : 3.7276906967163086, model weight : -1.8791345357894897, sample : tensor([1.9965, 0.0643])
# => proposal weight : 2.7923784255981445, model weight : -23.19502067565918, sample : tensor([2.0392, 0.1062])
# => proposal weight : 3.7274670600891113, model weight : -2.382697582244873, sample : tensor([1.9974, 0.0716])
# => proposal weight : 0.5724925994873047, model weight : -17.669370651245117, sample : tensor([1.9088, 0.1027])
# => proposal weight : 1.575183391571045, model weight : -23.9158878326416, sample : tensor([ 2.0874, -0.0994])
# => proposal weight : 3.5539493560791016, model weight : -3.7802791595458984, sample : tensor([1.9908, 0.1202])
# => proposal weight : 3.6852831840515137, model weight : -5.183596611022949, sample : tensor([2.0062, 0.0832])
# => proposal weight : 0.2941708564758301, model weight : -7.533394813537598, sample : tensor([1.9039, 0.2672])
# => proposal weight : 2.3133132457733154, model weight : -5.87722635269165, sample : tensor([ 1.9599, -0.0060])
# => proposal weight : 3.34736967086792, model weight : -0.4476358890533447, sample : tensor([1.9862, 0.0064])
# => proposal weight : 2.5222795009613037, model weight : -4.0601806640625, sample : tensor([ 2.0447, -0.1136])
# => proposal weight : 2.8992297649383545, model weight : -17.19761848449707, sample : tensor([2.0171, 0.1530])
# => proposal weight : 1.087643027305603, model weight : -4.2730536460876465, sample : tensor([ 2.0564, -0.1950])
# => proposal weight : 3.7184157371520996, model weight : -1.6927164793014526, sample : tensor([2.0034, 0.0326])
# => proposal weight : 1.721429467201233, model weight : -3.3604044914245605, sample : tensor([ 2.0479, -0.1636])
# => proposal weight : 2.6020853519439697, model weight : -4.3415374755859375, sample : tensor([1.9581, 0.0241])
# => proposal weight : 3.436581611633301, model weight : -9.086322784423828, sample : tensor([2.0078, 0.1212])
# => proposal weight : 2.698686361312866, model weight : -1.8586008548736572, sample : tensor([1.9504, 0.1780])
# => proposal weight : 1.5607547760009766, model weight : -11.495471954345703, sample : tensor([ 1.9448, -0.0039])
# => proposal weight : 2.65147066116333, model weight : -1.9055651426315308, sample : tensor([1.9480, 0.1752])
# => proposal weight : 1.6649364233016968, model weight : -2.734283924102783, sample : tensor([ 2.0431, -0.1664])
# => proposal weight : 3.19797420501709, model weight : -7.125632286071777, sample : tensor([1.9906, 0.1639])
# => proposal weight : 1.916011095046997, model weight : -3.2553014755249023, sample : tensor([1.9405, 0.2399])
# => proposal weight : 3.675358295440674, model weight : -2.959726333618164, sample : tensor([2.0147, 0.0133])
# => proposal weight : 3.432468891143799, model weight : -0.37026333808898926, sample : tensor([ 1.9994, -0.0126])
# => proposal weight : 0.4759470224380493, model weight : -33.300262451171875, sample : tensor([ 2.1069, -0.1288])
# => proposal weight : 2.047919273376465, model weight : -27.638591766357422, sample : tensor([ 2.0791, -0.0360])
# => proposal weight : 3.6609091758728027, model weight : -5.757479190826416, sample : tensor([2.0069, 0.0880])
# => proposal weight : 3.0877928733825684, model weight : -1.0257869958877563, sample : tensor([ 2.0178, -0.0668])
# => proposal weight : 1.6558451652526855, model weight : -32.71784973144531, sample : tensor([2.0291, 0.2004])
# => proposal weight : 2.2138266563415527, model weight : -5.921270370483398, sample : tensor([1.9363, 0.1013])
# => proposal weight : 2.722898483276367, model weight : -3.2356300354003906, sample : tensor([ 1.9691, -0.0041])
# => proposal weight : 3.04443359375, model weight : -0.7257615327835083, sample : tensor([ 2.0126, -0.0661])
# => proposal weight : 3.4997973442077637, model weight : -10.519699096679688, sample : tensor([2.0303, 0.0456])
# => proposal weight : 3.6672282218933105, model weight : -5.997373580932617, sample : tensor([2.0091, 0.0824])
# => proposal weight : 3.607546806335449, model weight : -1.7523859739303589, sample : tensor([ 2.0120, -0.0028])
# => proposal weight : 1.8560314178466797, model weight : -5.986640930175781, sample : tensor([ 1.9791, -0.0833])
# => proposal weight : 3.3573861122131348, model weight : -2.205498218536377, sample : tensor([ 2.0227, -0.0419])
# => proposal weight : 3.5124917030334473, model weight : -0.2921633720397949, sample : tensor([1.9894, 0.0203])
# => proposal weight : 1.5948123931884766, model weight : -3.8468918800354004, sample : tensor([1.9266, 0.2302])
# Sample size: 3000
# Effective sample size: tensor(883.6479)
# Fractional sample size: tensor(0.2945)
# Sum of weights: tensor(1.)

# %%
df1 = pd.DataFrame(proposal_samples, columns = ["slope", "bias"])
df2 = pd.DataFrame(samples, columns = ["slope", "bias"])
samples_dict = {"proposal" : {"slope" : df1["slope"].to_numpy(), "bias" : df1["bias"].to_numpy()},
                "posterior" :{"slope" : df2["slope"].to_numpy(), "bias" : df2["bias"].to_numpy()}}

# %%
# Make a triangle plot to see slope and bias distributions and correlations
def triangle_plot(samples_dict, mu=None, cov=None, **kwargs):
    plt.subplots(2, 2, **kwargs)
    plt.subplot(2, 2, 1)
    for name, samples in samples_dict.items():
        plt.hist(samples['bias'], alpha=0.7, density=True, bins='auto', label=name)
    if mu is not None and cov is not None:
        x, f = get_distribution(plt, mu[0], np.sqrt(cov[0, 0]))
        plt.plot(x, f, color='black', label='analytical')
    plt.gca().set_xticklabels([])
    plt.yticks([])
    plt.legend(prop={'size': 12})
    plt.subplot(2, 2, 4)
    for name, samples in samples_dict.items():
        plt.hist(samples['slope'], alpha=0.7, density=True, bins='auto', label=name)
    if mu is not None and cov is not None:
        x, f = get_distribution(plt, mu[1], np.sqrt(cov[1, 1]))
        plt.plot(x, f, color='black', label='analytical')
    plt.xlabel('slope')
    plt.yticks([])
    plt.subplot(2, 2, 3)
    for name, samples in samples_dict.items():
        plt.scatter(samples['bias'], samples['slope'], alpha=0.5, s=5., label=name)
    if mu is not None and cov is not None:
        X, Y, Z = get_contours(plt, mu, cov)
        plt.contour(X, Y, Z, colors='black', alpha=0.9, levels=3)
    plt.xlabel('bias')
    plt.ylabel('slope')
    plt.subplot(2, 2, 2).axis('off')
    plt.tight_layout()
    plt.show()

# Plot the learning curves to see how training is progressing
def plot_learning_curve(training_logfile, **kwargs):
    data = np.loadtxt(training_logfile, skiprows=1, delimiter=',', converters={8: lambda _: 0.})
    plt.figure(**kwargs)
    plt.plot(data[:, 1], data[:, 3], label='training')
    plt.xlabel('Training iteration')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Analytical expression for the posterior covariance
def analytical_covariance(x, sigma, alpha):
    cov1 = np.identity(2)*(sigma/alpha)**2
    x0_sum = len(x)
    x1_sum = np.sum(x)
    x2_sum = np.sum(x**2)
    cov2 = np.array([
        [x0_sum, x1_sum],
        [x1_sum, x2_sum],
    ])
    cov = (1./sigma**2)*(cov1+cov2)
    cov = np.linalg.inv(cov)
    return cov

# Analytical expression for the posterior mean
def analytical_mean(x, y, sigma, alpha):
    xy_sum = np.sum(x*y)
    y_sum = np.sum(y)
    vec = np.array([y_sum, xy_sum])
    cov = analytical_covariance(x, sigma, alpha)
    mu = np.matmul(cov, vec)/sigma**2
    return mu

# Distribution for 1D marginal posteriors
def get_distribution(plt, mu, sig, N=200):
    xlim = plt.gca().get_xlim()
    x = np.linspace(xlim[0], xlim[1], N)
    rv = norm(mu, sig)
    f = rv.pdf(x)
    return x, f

# Contours for 2D posterior distributions
def get_contours(plt, mu, cov, N=200):
    xlim = plt.gca().get_xlim(); ylim = plt.gca().get_ylim()
    X = np.linspace(xlim[0], xlim[1], N)
    Y = np.linspace(ylim[0], ylim[1], N)
    X, Y = np.meshgrid(X, Y); pos = np.dstack((X, Y))
    rv = multivariate_normal(mu, cov)
    Z = rv.pdf(pos)
    return X, Y, Z

# %%
x = np.array([1., 2., 3., 4., 5., 6.])
sigma = 0.1  # Likelihood error
alpha = 10.0 # Prior scale
obs_np = observed.numpy()
mu = analytical_mean(np.array(x), np.sort(obs_np), sigma, alpha)
cov = analytical_covariance(np.array(x), sigma, alpha)
print(mu, " +- ", np.sqrt(cov.diagonal()))
print(cov)
# Out:
# [0.01403638 1.99027512]  +-  [0.09309068 0.02390367]
# [[ 0.00866588 -0.00199982]
#  [-0.00199982  0.00057139]]

# %%
triangle_plot(samples_dict, mu, cov, figsize=(8,8))

# %%
observed = []
for var in model.topological():
    if var in model.Graph["Y"].keys():
        observed.append(tc.tensor(model.Graph["Y"][var]).float())

observed = tc.stack(observed)

observed_test1 = np.random.normal(1 * x + 3, scale = sigma)
observed_test1 = tc.tensor(observed_test1[observed.argsort().argsort()]).float()

observed_test2 = np.random.normal(5 * x + 8, scale = sigma)
observed_test2 = tc.tensor(observed_test2[observed.argsort().argsort()]).float()

observed_test3 = np.random.normal(9 * x + 13, scale = sigma)
observed_test3 = tc.tensor(observed_test3[observed.argsort().argsort()]).float()

# %%
def plot_proposal_by_epochs(epochs : int, observed : tc.Tensor, model, num_samples = 2000, **kwargs):
    
    latents = [var for var in model.topological() if var.startswith("sample")]
    fig, axs = plt.subplots(2, epochs, **kwargs)

    x = np.array([1., 2., 3., 4., 5., 6.])
    mu = analytical_mean(np.array(x), np.sort(observed), sigma, alpha)
    cov = analytical_covariance(np.array(x), sigma, alpha)

    for i, latent in enumerate(latents):
        for epoch in range(epochs):
            with open(run + "proposal_epoch{}.pkl".format(epoch), "rb") as f:
                proposal = pickle.load(f)
            
            proposal_samples = []
            for _ in range(num_samples):
                sample = proposal.sample(y = observed)[latent]
                proposal_samples.append(sample)

            proposal_samples = tc.stack(proposal_samples).numpy()
            axs[i,epoch].hist(proposal_samples, bins="auto", label="Epoch {}".format(epoch + 1), density=True)
            xlim = axs[i,epoch].get_xlim()
            x = np.linspace(xlim[0], xlim[1], 5000)
            rv = norm(mu[1-i], np.sqrt(cov[1-i,1-i]))
            f = rv.pdf(x)
            
            axs[i,epoch].plot(x, f, label="Analytical posterior")

            axs[i,epoch].legend(loc="upper right", prop = {"size" : 12})
    
    axs[0,0].set_ylabel("slope")
    axs[1,0].set_ylabel("bias")

# %%
plot_proposal_by_epochs(epochs=7, observed=observed, model=model, num_samples=3000, figsize=(26,10))
print(observed.sort())
# y = 2x + 0
# Out:
# torch.return_types.sort(
# values=tensor([ 2.0500,  3.9400,  5.9000,  8.0300, 10.1000, 11.8600]),
# indices=tensor([5, 3, 0, 4, 2, 1]))

# %%
plot_proposal_by_epochs(epochs=7, observed=observed_test1, model=model, figsize=(20,8))
print(observed_test1.sort())
# y = x + 3
# Out:
# torch.return_types.sort(
# values=tensor([3.9494, 4.9548, 5.8313, 7.0786, 8.1524, 9.1087]),
# indices=tensor([5, 3, 0, 4, 2, 1]))

# %%
plot_proposal_by_epochs(epochs=7, observed=observed_test2, model=model, figsize=(20,8))
# y = 5x + 8

# %%
plot_proposal_by_epochs(epochs=7, observed=observed_test3, model=model, figsize=(20,8))
# y = 9x + 13

# %%
def plot_losses(**kwargs):
    losses = tc.load(run + "losses.pt")
    fig, axs = plt.subplots(1, len(losses), **kwargs)
    for i, loss in enumerate(losses):
        axs[i].plot(loss, label="epoch {}".format(i))
        axs[i].legend()
    return

# %%
plot_losses(figsize=(20,4))
